# %% [markdown]
# # Lee Yik Kai (24304348)
#
# ---
#
#
# #Project Title: TravelGo Hotel Review System
#
# **Google Colab Link:**
# https://colab.research.google.com/drive/1cfPAl8hXDsGZ-o9dgt8nvDvmZatyU_pi#scrollTo=EctKs0bBQldV
#
# ##Project Specification:
#
# Nowadays, hotel reviews play a vital role in helping travelers make informed decisions when choosing accommodation. As online booking platforms continue to grow, there is an increasing demand for a structured and reliable system to manage hotel reviews and user information efficiently. In response to this need, the **TravelGo Hotel Review System** has been developed to support TravelGo, a global hotel booking and review platform.
#
# **TravelGo Hotel Review System** is a comprehensive solution designed to manage hotel review data and user activity in an organized manner. The system allows users to explore available hotels, read existing reviews, and submit new reviews with ratings and written feedback. To encourage user participation, a points-based mechanism is implemented to track user activity, evaluate engagement, and automatically update membership categories based on accumulated points.
#
# In this documentation, the features and functionalities of the TravelGo Hotel Review System will be discussed in detail. The report explains how the system operates, the algorithms used to process reviews and user data, as well as the methods applied to update membership categories. Additionally, the limitations and constraints of the system are examined to provide a clear understanding of its scope. Ultimately, this report aims to present a functional and user-friendly program that supports TravelGo in managing hotel reviews while enhancing user engagement.

# %% [markdown]
# # Problem Analysis

# %% [markdown]
# ##**What is the Problem?**
# Problem :
#
# Develop a program that utilises file handling to manage hotel reviews and user information efficiently. The system should be able to list all reviews based on selected hotels and the reviewer’s UserID or Username. When a new review is added, the hotel’s average rating must be updated accordingly. The program must read data from existing files and allow new information to be added through user input. For each new review, the hotel’s average rating and total number of reviews must be recalculated, and the entered information should be appended to the existing files to be used as input in the next program execution.
#
# In addition, the system should track user activity by assigning points for each review submitted and automatically update the user’s membership category based on accumulated points. The program should operate continuously until the user chooses to exit. Appropriate features must be designed and managed through an interactive program menu. These features should be relevant to hotel reviews and user engagement within the TravelGo platform.
#
# <br>
#
# The program should have the following functionalities:
#
# 1. Read user information and hotel review data from input files.
# 2. Provide a menu-driven interface for users to navigate the system.
# 3. Allow the program to run continuously until the user chooses to exit.
# 4. Display all reviews written by a specific user.
# 5. Display all reviews for a specific hotel.
# 6. Allow users to submit a new hotel review, including rating and review statement.
# 7. Automatically calculate and update user's current points based on review activity.
# 8. Automatically update the user’s membership category.
# 9. Display an appropriate notification message when there is a change in membership category.
# 10. Automatically update the total number of reviews and average rating for each hotel.
# 11. Display the user’s latest information, including current points, and membership category.
# 12. Provide search functionality for reviews based on keywords.
# 13. Sort and display users or hotels based on relevant criteria such as current points, ratings, or review count.
# 14. Validate user input and display error messages for invalid selections or data.
# 15. Save all updated user and review information back to the files before the program exits.
#
# <br>
#
# ---

# %% [markdown]
# ##**Assumptions for the TravelGo Hotel Review System:**
#
# **Pre-existing Data:**
# 1. It is assumed that the source files **users.txt** and **review.txt** are pre-created and located in the same directory as the program executable.
# 2. The data stored in the input files is assumed to be in the correct and predefined format. It expects specific data types in specific columns (e.g., integers for points/ratings, strings for names) to ensure the read file functions operate without errors.
# 3. It is assumed that every UserID listed in **review.txt** corresponds to a valid, existing user in **users.txt**. There are no "orphan" reviews; the system assumes that any user who has left a review is already fully registered in the user database.
#
# **Data Integrity:**
# 1. The program utilizes fixed-size arrays for memory management. It is assumed that the total number of users and reviews will not exceed the defined limit of 100 entries during the execution of the program.
# 2. For the point calculation algorithm, it is assumed that words in a review statement are separated by single spaces. The system counts words based on space delimiters to award the "Long Review Bonus" (10 points per 50 words).
# 3. It is assumed that the rating for every review is always an integer and falls strictly within the valid range of 1 to 5.
# 4. The system calculates the total number of reviews for each user by dividing their Current Points by 100. This assumes that all historical reviews were under 50 words and therefore did not earn any "Long Review Bonus" points.
#
#
# **Focus on New Reviews:**
# 1. It is assumed that no new users will be registered during the program's runtime. When submitting a review, the entered UserID must match an existing record in users.txt. The system does not support creating new user profiles; it only processes activities for pre-registered users.
# 2. Unlike users, it is assumed that new hotels can be introduced to the system at any time. If a user submits a review for a hotel that does not currently exist in the database, the system accepts it as a valid new entry and begins tracking statistics for that hotel immediately.
# 3. It is assumed that when a user inputs a hotel name for a new review, the capitalization exactly matches the existing records. Since the system treats case variations as distinct entities, it is assumed that users will adhere to the established capitalization format to ensure the review is correctly assigned to the intended hotel.
#
# <br>
#
# ---

# %% [markdown]
# ##**What Input, Process and Output**
# **Input**
#
# 1. Input Files (Pre-existing Data):
#
# - The system reads from text files using tab-separated values to load initial data:
#
#   - users.txt: Contains UserID, Username, Country, State, Email, Membership Category, and Current Points.
#
#   - review.txt: Contains UserID, Rating, Review Statement, and Hotel Name.
#
# 2. Menu Selection:
#
# - The user selects options from the main menu (1 to 12) to navigate features:
#
#   - Menu 1-2: Display reviews for users or hotels.
#
#   - Menu 3: View user information.
#
#   - Menu 4: View positive hotel reviews only.
#
#   - Menu 5-9: View summaries, memberships, leaderboards, and rating stats.
#
#   - Menu 10: Add a new review.
#
#   - Menu 11: Search reviews by keyword.
#
#   - Menu 12: Save and Exit the program.
#
# 3. User Inputs (Runtime Interaction):
#
# - Specific Data Retrieval:
#
#   - User ID string (e.g., "U001") to search for specific user reviews.
#
#   - Hotel Index Integer to select a hotel from the available list.
#
#   - Keyword string to search within review statements.
#
# - New Review Submission:
#
#   - User ID: Must match an existing ID in users.txt.
#
#   - Hotel Name: String input (spaces allowed).
#
#   - Review Statement: Text description of the experience.
#
#   - Rating: Numeric value strictly between 1 and 5.
#
# - Sorting Options:
#
#   - Input 1 for Ascending or 2 for Descending order when viewing lists.
#
# <br>
#
# **Process**
#
# 1. File Operations:
#
# - Reading Data:
#
#   - Reads users.txt and review.txt into parallel arrays upon startup.
#
# - Writing Data:
#
#   - Overwrites users.txt and review.txt with updated arrays only when the "Save & Exit" option is triggered.
#
# 2. Gamification Logic:
#
# - Points Calculation:
#
#   - Calculates total points awarded based on the number of reviews (100 points each).
#
#   - Adds a "Length Bonus" of 10 points for every 50 words in a review statement.
#
# - Membership Updates:
#
#   - Automatically checks user points against thresholds (Basic < 1000, Silver < 5000, Gold < 10000, Platinum > 10000).
#
#   - Updates the user's category if they cross a threshold.
#
# 3. Statistical Calculations:
#
# - Hotel Statistics:
#
#   - Iterates through review arrays to count the total number of reviews per hotel.
#
#   - Calculates the average rating for each hotel dynamically.
#
# - Leaderboard Generation:
#
#   - Sorts users based on their review count (derived from current points) using a bubble sort algorithm.
#
# 4. Search and Filter Algorithms:
#
# - Keyword Search:
#
#   - Converts user input and review statements to lowercase to perform case-insensitive substring matching.
#
# - High Rating Filter:
#
#   - Filters the review array to display only entries where the rating is 4 or 5.
#
# <br>
#
# **Output**
#
# 1. Terminal Outputs (Visual Interface):
#
# - Menu Interface:
#
#   - Displays a structured list of 12 options with ANSI color coding.
#
# - Formatted Data Tables:
#
#   - User Profiles: Displays ID, Username, Email, Membership, and Points in a table.
#
#   - Review Lists: Displays User ID, Rating, Statement, and Hotel Name for selected views.
#
# - Analytical Reports:
#
#   - Leaderboards: Rankings of top reviewers sorted by activity.
#
#   - Hotel Summaries: A statistical summary table showing average ratings and total reviews per hotel.
#
# 2. System Notifications:
#
# - Error Messages:
#
#   - Displays Red text for invalid inputs (e.g., "User not found!", "Invalid Choice").
#
# - Success Messages:
#
#   - Displays Yellow text to confirm successful operations, such as "Latest review data have been successfully updated" or "Data successfully added."
#
# - Upgrade Alerts:
#
#   - Displays a notification in Cyan whenever the system detects that one or multiple users have qualified for a membership tier upgrade.
#
# - Exit Message:
#
#   - Displays a polite closing message ("Thank you for using this system!") to acknowledge the user before the program terminates.
#
# 3. File Output:
#
# - users.txt: Updated with the latest points and membership status.
#
# - review.txt: Appended with all new reviews entered during the session.
#
# <br>
#
# ---

# %% [markdown]
# ##**Constraints, Limitations and Challenges**
# This program is subject to several constraints and limitations that may impact its performance during operation, as well as specific technical requirements for execution.

# %% [markdown]
# ###**Constraints**
#
# 1. System Capacity:
# - The program utilizes fixed-size arrays for memory management, strictly limiting the system to 100 users and 100 reviews. Exceeding this capacity would require modifying the source code and recompiling the application.
#
# 2. File Dependencies:
# - The program relies on the existence of two specific files (users.txt and review.txt) formatted with tab-separated values. If these files are missing, corrupted, or located in a different directory, the read functions will fail, and the program cannot function.
#
# 3. Hardware Requirements:
#
# - Processor (CPU): Any standard processor (x86, x64, ARM) capable of executing compiled C++ code is suitable.
#
# - I/O Devices: The program requires a standard keyboard for input (menu selection, review typing) and a monitor supporting ANSI colors for output.
#
# 4. Software Dependencies:
#
# - Compiler: A C++ compiler (such as GCC, Clang, or MSVC) is required to translate the source code into machine code.
#
# - Operating System: The program is cross-platform but requires a terminal environment that supports ANSI escape codes (e.g., Linux Terminal, macOS Terminal, or modern Windows CMD/PowerShell) to correctly render the UI colors (Blue, Red, Yellow).

# %% [markdown]
# ###**Limitations**
#
# 1. Static User Database:
# - A primary functional limitation is that the program does not support registering new users during runtime. It operates on a closed system where all valid users must be pre-loaded in the users.txt file. Any new user registration requires manual file editing outside the program environment.
#
# 2. User Interface (CLI):
# - Currently, the program only supports a Command-Line Interface (CLI). This may not be beginner-friendly compared to a Graphical User Interface (GUI), and users must rely on keyboard navigation (1-12) rather than mouse clicks.
#
# 3. Data Volatility:
# - The system uses an in-memory approach where data is updated in variables and only written back to files upon selecting "Save & Exit." If the program crashes or is force-closed, any new reviews or point updates made during that session are permanently lost.
#
# 4. Concurrency:
# - The program is designed for a single administrator. Simultaneous access (e.g., two users trying to write to review.txt at once) is not supported and may result in data corruption.

# %% [markdown]
# ###**Challenges**
#
# 1. Gamification Logic Implementation:
# - A significant challenge was implementing the "Long Review Bonus" algorithm. This required parsing review statements character-by-character to count words (using space delimiters) and dynamically calculating points (Word Count / 50) * 10 while handling different string lengths without errors.
#
# 2. Data Synchronization:
# - Managing parallel arrays (keeping user_id[], user_name[], and current_points[] synced) was complex. Specifically, implementing the Leaderboard feature required a Bubble Sort algorithm that swaps elements across multiple arrays simultaneously to ensure user data remained linked correctly.
#
# 3. Error Handling:
# - Ensuring the program handles invalid inputs gracefully was critical. The system had to be robust enough to handle data type mismatches (e.g., entering a letter when a number was expected for a menu choice) by using input stream clearing (cin.ignore) to prevent infinite loops or crashes.
#
# <br>
#
# ---

# %% [markdown]
# #Programming Design & Solution

# %% [markdown]
# ##Pseudocode
#
# These **step-by-step instructions** are designed to provide you with a comprehensive understanding of the concepts and working flow of the TravelGo Hotel Review System.

# %% [markdown]
# ```
# CONSTANT MAX_USERS = 100
# CONSTANT MAX_REVIEWS = 100
#
# BEGIN MainProgram
#
#     DECLARE user_id, user_name, country, state, email, membership_category, current_points AS ARRAYS
#     DECLARE review_user_id, review_rating, review_statement, review_hotel_name AS ARRAYS
#     DECLARE hotel_name, number_review_hotel, total_rating_hotel AS ARRAYS
#     DECLARE number_word_review_statement AS ARRAY
#
#     DECLARE copy_membership_category AS ARRAY
#     DECLARE copy_user_id, copy_user_name, copy_current_points, sort_membership_category AS ARRAYS
#     DECLARE copy_hotel_name, copy_number_review_hotel, copy_total_rating_hotel AS ARRAYS
#     DECLARE count_review AS ARRAY
#
#     DECLARE num_user, num_review, num_hotel, total_points, choice, i AS INTEGERS
#
#     SET num_user = CALL readUsers()
#     SET num_review = CALL readReview()
#
#     CALL calculateNumWordReviewStatement(num_review)
#     SET total_points = CALL recalculatePoints(num_user, num_review)
#
#     FOR i = 0 TO num_user - 1 DO
#         copy_membership_category[i] = membership_category[i]
#     END FOR
#     CALL updateMembershipCategory(num_user, copy_membership_category)
#
#     SET num_hotel = CALL calculateNumHotel(num_review)
#     CALL calculateNumReviewHotel(num_hotel, num_review)
#
#     SET choice = 0
#     WHILE choice != 12 DO
#         DISPLAY "TravelGo Main Menu (1-12)"
#         INPUT choice
#
#         WHILE choice < 1 OR choice > 12 DO
#             DISPLAY "Invalid Choice!"
#             INPUT choice
#         END WHILE
#
#         SWITCH choice DO
#             CASE 1:
#                 INPUT target_user_id
#                 CALL displaySpecificUserReview(target_user_id, num_user, num_review)
#
#             CASE 2:
#                 DISPLAY hotel_list with index
#                 INPUT hotel_index
#                 CALL displaySpecificHotelReview(hotel_index, num_hotel, num_review, num_user)
#
#             CASE 3:
#                 CALL displayUserLatestInfo(num_user)
#
#             CASE 4:
#                 DISPLAY hotel_list with index
#                 INPUT hotel_index
#                 CALL displayHighRatingReview(hotel_index, num_hotel, num_review, num_user)
#
#             CASE 5:
#                 CALL displaySummaryActivities(num_user, num_review, total_points)
#
#             CASE 6:
#                 FOR i = 0 TO num_user - 1 DO
#                     copy_user_id[i] = user_id[i]
#                     copy_user_name[i] = user_name[i]
#                     copy_current_points[i] = current_points[i]
#                     sort_membership_category[i] = membership_category[i]
#                 END FOR
#                 CALL displayUsersByMembership(num_user)
#
#             CASE 7:
#                 FOR i = 0 TO num_user - 1 DO
#                     copy_user_id[i] = user_id[i]
#                     copy_user_name[i] = user_name[i]
#                     copy_current_points[i] = current_points[i]
#                 END FOR
#                 CALL displayTopReviewerLeaderboard(num_user)
#
#             CASE 8:
#                 FOR i = 0 TO num_user - 1 DO
#                     copy_user_id[i] = user_id[i]
#                     copy_user_name[i] = user_name[i]
#                     copy_current_points[i] = current_points[i]
#                 END FOR
#                 CALL displayTop3Reviewer(num_user)
#
#             CASE 9:
#                 FOR i = 0 TO num_hotel - 1 DO
#                     copy_hotel_name[i] = hotel_name[i]
#                     copy_number_review_hotel[i] = number_review_hotel[i]
#                     copy_total_rating_hotel[i] = total_rating_hotel[i]
#                 END FOR
#                 CALL displayHotelRatingSummary(num_hotel)
#
#             CASE 10:
#                 SET num_hotel = CALL addNewReview(num_review, num_user)
#                 SET num_review = num_review + 1
#
#                 FOR i = 0 TO num_user - 1 DO
#                     copy_membership_category[i] = membership_category[i]
#                 END FOR
#
#                 CALL recalculatePoints(num_user, num_review)
#                 CALL updateMembershipCategory(num_user, copy_membership_category)
#
#             CASE 11:
#                 INPUT keyword
#                 CALL searchReviewByWord(num_review, num_user, keyword)
#
#         END SWITCH
#     END WHILE
#
#     CALL updateUserFile(num_user)
#     CALL updateReviewFile(num_review)
#     DISPLAY "Thank you for using this system!"
# END MainProgram
#
# FUNCTION readUsers()
#     OPEN "users.txt" FOR READING
#     SET count = 0
#     WHILE NOT EndOfFile AND count < MAX_USERS DO
#         READ user_id[count], user_name[count], country[count], state[count], email[count], membership_category[count], current_points[count]
#         SET count = count + 1
#     END WHILE
#     CLOSE file
#     RETURN count
# END FUNCTION
#
# FUNCTION readReview()
#     OPEN "review.txt" FOR READING
#     SET count = 0
#     WHILE NOT EndOfFile AND count < MAX_REVIEWS DO
#         READ review_user_id[count]
#         READ temp_rating
#         SET review_rating[count] = STRING_TO_INT(temp_rating)
#         READ review_statement[count]
#         READ review_hotel_name[count]
#         SET count = count + 1
#     END WHILE
#     CLOSE file
#     RETURN count
# END FUNCTION
#
# FUNCTION updateUserFile(num_user)
#     OPEN "users.txt" FOR WRITING
#     FOR i = 0 TO num_user - 1 DO
#         WRITE user_id[i], user_name[i], country[i], state[i], email[i], membership_category[i], current_points[i]
#     END FOR
#     CLOSE file
# END FUNCTION
#
# FUNCTION updateReviewFile(num_review)
#     OPEN "review.txt" FOR WRITING
#     FOR i = 0 TO num_review - 1 DO
#         WRITE review_user_id[i], review_rating[i], review_statement[i], review_hotel_name[i]
#     END FOR
#     CLOSE file
# END FUNCTION
#
# FUNCTION calculateNumWordReviewStatement(num_review)
#     FOR i = 0 TO num_review - 1 DO
#         SET text = review_statement[i]
#         SET count_words = 1
#         FOR EACH character c IN text DO
#             IF c == ' ' THEN
#                 SET count_words = count_words + 1
#             END IF
#         END FOR
#         SET number_word_review_statement[i] = count_words
#     END FOR
# END FUNCTION
#
# FUNCTION recalculatePoints(num_user, num_review)
#     SET total_system_points = 0
#     FOR i = 0 TO num_user - 1 DO
#         SET count_review = 0
#         SET bonus_count = 0
#
#         FOR j = 0 TO num_review - 1 DO
#             IF review_user_id[j] == user_id[i] THEN
#                 SET count_review = count_review + 1
#                 IF number_word_review_statement[j] > 50 THEN
#                     SET bonus_count = bonus_count + (number_word_review_statement[j] / 50)
#                 END IF
#             END IF
#         END FOR
#
#         SET points_gain = (count_review * 100) + (bonus_count * 10)
#         SET current_points[i] = current_points[i] + points_gain
#         SET total_system_points = total_system_points + points_gain
#     END FOR
#     RETURN total_system_points
# END FUNCTION
#
# FUNCTION updateMembershipCategory(num_user, copy_membership_category[])
#     SET updated = FALSE
#     FOR i = 0 TO num_user - 1 DO
#         SET pts = current_points[i]
#
#         IF pts < 1000 THEN
#             SET membership_category[i] = "Basic"
#         ELSE IF pts < 5000 THEN
#             SET membership_category[i] = "Silver"
#         ELSE IF pts < 10000 THEN
#             SET membership_category[i] = "Gold"
#         ELSE
#             SET membership_category[i] = "Platinum"
#         END IF
#
#         IF membership_category[i] != copy_membership_category[i] THEN
#             SET updated = TRUE
#         END IF
#     END FOR
#
#     IF updated IS TRUE THEN
#         DISPLAY "Membership Upgrade Notification Table"
#         FOR i = 0 TO num_user - 1 DO
#             IF membership_category[i] != copy_membership_category[i] THEN
#                 DISPLAY user_id[i], user_name[i], copy_membership_category[i], membership_category[i]
#             END IF
#         END FOR
#     END IF
# END FUNCTION
#
# FUNCTION calculateNumHotel(num_review)
#     SET num_hotel = 0
#     FOR i = 0 TO num_review - 1 DO
#         SET found = FALSE
#         FOR j = 0 TO num_hotel - 1 DO
#             IF hotel_name[j] == review_hotel_name[i] THEN
#                 SET found = TRUE
#                 BREAK
#             END IF
#         END FOR
#
#         IF found == FALSE THEN
#             SET hotel_name[num_hotel] = review_hotel_name[i]
#             SET num_hotel = num_hotel + 1
#         END IF
#     END FOR
#     RETURN num_hotel
# END FUNCTION
#
# FUNCTION calculateNumReviewHotel(num_hotel, num_review)
#     FOR i = 0 TO num_hotel - 1 DO
#         SET number_review_hotel[i] = 0
#         SET total_rating_hotel[i] = 0
#         FOR j = 0 TO num_review - 1 DO
#             IF review_hotel_name[j] == hotel_name[i] THEN
#                 SET number_review_hotel[i] = number_review_hotel[i] + 1
#                 SET total_rating_hotel[i] = total_rating_hotel[i] + review_rating[j]
#             END IF
#         END FOR
#     END FOR
# END FUNCTION
#
# FUNCTION addNewReview(num_review, num_user)
#     SET user_found = FALSE
#     REPEAT
#         DISPLAY "Enter UserID"
#         INPUT input_user_id
#         FOR i = 0 TO num_user - 1 DO
#             IF user_id[i] == input_user_id THEN
#                 SET user_found = TRUE
#                 BREAK
#             END IF
#         END FOR
#         IF user_found == FALSE THEN
#             DISPLAY "Error: User not found"
#         END IF
#     UNTIL user_found == TRUE
#
#     INPUT input_hotel_name
#     INPUT input_statement
#     REPEAT
#         DISPLAY "Enter Rating (1-5)"
#         INPUT input_rating
#     UNTIL input_rating >= 1 AND input_rating <= 5
#
#     SET review_user_id[num_review] = input_user_id
#     SET review_hotel_name[num_review] = input_hotel_name
#     SET review_statement[num_review] = input_statement
#     SET review_rating[num_review] = input_rating
#
#     SET word_count = 0
#     FOR EACH character c IN input_statement DO
#         IF c == ' ' THEN
#             SET word_count = word_count + 1
#         END IF
#     END FOR
#     SET word_count = word_count + 1
#
#     FOR i = 0 TO num_user - 1 DO
#         IF user_id[i] == input_user_id THEN
#             SET current_points[i] = current_points[i] + 100
#             IF word_count >= 50 THEN
#                 SET current_points[i] = current_points[i] + ((word_count / 50) * 10)
#             END IF
#         END IF
#     END FOR
#
#     SET updated_num_hotel = CALL calculateNumHotel(num_review + 1)
#     CALL calculateNumReviewHotel(updated_num_hotel, num_review + 1)
#
#     RETURN updated_num_hotel
# END FUNCTION
#
# FUNCTION displayHotelRatingSummary(num_hotel)
#     DISPLAY "1. Sort by Count, 2. Sort by Rating"
#     INPUT criteria
#     DISPLAY "1. Ascending, 2. Descending"
#     INPUT order
#
#     FOR i = 0 TO num_hotel - 2 DO
#         FOR j = i + 1 TO num_hotel - 1 DO
#
#             SET should_swap = FALSE
#
#             IF criteria == 1 THEN
#                 IF (order == 1 AND copy_number_review_hotel[j] < copy_number_review_hotel[i]) OR (order == 2 AND copy_number_review_hotel[j] > copy_number_review_hotel[i]) THEN
#                     SET should_swap = TRUE
#                 END IF
#             ELSE
#                 SET avg_i = copy_total_rating_hotel[i] / copy_number_review_hotel[i]
#                 SET avg_j = copy_total_rating_hotel[j] / copy_number_review_hotel[j]
#
#                 IF (order == 1 AND avg_j < avg_i) OR (order == 2 AND avg_j > avg_i) THEN
#                     SET should_swap = TRUE
#                 END IF
#             END IF
#
#             IF should_swap IS TRUE THEN
#                 SWAP elements at [i] and [j] for copy_hotel_name, copy_number_review_hotel, copy_total_rating_hotel
#             END IF
#
#         END FOR
#     END FOR
#
#     DISPLAY "Hotel Rating Summary Table"
#     FOR i = 0 TO num_hotel - 1 DO
#             SET average = copy_total_rating_hotel[i] / copy_number_review_hotel[i]
#             DISPLAY copy_hotel_name[i], average, copy_number_review_hotel[i]
#     END FOR
# END FUNCTION
#
# FUNCTION sortUsersNumReview(num_user)
#     FOR i = 0 TO num_user - 2 DO
#         FOR j = i + 1 TO num_user - 1 DO
#             IF count_review[j] > count_review[i] THEN
#                 SWAP elements at [i] and [j] for copy_user_id, copy_user_name, count_review, copy_current_points
#             END IF
#         END FOR
#     END FOR
# END FUNCTION
#
# FUNCTION displayTopReviewerLeaderboard(num_user)
#     FOR i = 0 TO num_user - 1 DO
#         SET count_review[i] = copy_current_points[i] / 100
#     END FOR
#
#     CALL sortUsersNumReview(num_user)
#
#     DISPLAY "Top Reviewer Leaderboard"
#     SET rank = 1
#     FOR i = 0 TO num_user - 1 DO
#         IF i > 0 AND count_review[i] != count_review[i-1] THEN
#             SET rank = i + 1
#         END IF
#
#         DISPLAY rank, copy_user_id[i], copy_user_name[i], count_review[i]
#     END FOR
# END FUNCTION
#
# FUNCTION displayTop3Reviewer(num_user)
#     FOR i = 0 TO num_user - 1 DO
#         SET count_review[i] = copy_current_points[i] / 100
#     END FOR
#
#     CALL sortUsersNumReview(num_user)
#
#     SET rank = 1
#     FOR i = 0 TO num_user - 1 DO
#         IF i > 0 AND count_review[i] != count_review[i-1] THEN
#             SET rank = i + 1
#         END IF
#
#         IF rank <= 3 THEN
#             DISPLAY rank, copy_user_id[i], copy_user_name[i], count_review[i]
#         END IF
#     END FOR
# END FUNCTION
#
# FUNCTION displayUsersByMembership(num_user)
#     DISPLAY "1. Ascending, 2. Descending"
#     INPUT sort_order
#
#     FOR i = 0 TO num_user - 2 DO
#         FOR j = i + 1 TO num_user - 1 DO
#             IF (sort_order == 1 AND copy_current_points[j] < copy_current_points[i]) OR (sort_order == 2 AND copy_current_points[j] > copy_current_points[i]) THEN
#                 SWAP elements at [i] and [j] for copy_user_id, copy_user_name, copy_current_points, sort_membership_category
#             END IF
#         END FOR
#     END FOR
#
#     CALL innerDisplayUsersByMembership("Platinum", num_user)
#     CALL innerDisplayUsersByMembership("Gold", num_user)
#     CALL innerDisplayUsersByMembership("Silver", num_user)
#     CALL innerDisplayUsersByMembership("Basic", num_user)
# END FUNCTION
#
# FUNCTION innerDisplayUsersByMembership(target_category, num_user)
#     DISPLAY "Category: " + target_category
#     SET found = FALSE
#     FOR i = 0 TO num_user - 1 DO
#         IF sort_membership_category[i] == target_category THEN
#             DISPLAY copy_user_id[i], copy_user_name[i], copy_current_points[i]
#             SET found = TRUE
#         END IF
#     END FOR
#     IF found == FALSE THEN
#         DISPLAY "No users in this category"
#     END IF
# END FUNCTION
#
# FUNCTION displaySpecificUserReview(input_user_id, num_user, num_review)
#     SET user_found = FALSE
#     SET review_found = FALSE
#
#     FOR i = 0 TO num_user - 1 DO
#         IF user_id[i] == input_user_id THEN
#             SET user_found = TRUE
#         END IF
#     END FOR
#
#     FOR i = 0 TO num_review - 1 DO
#         IF review_user_id[i] == input_user_id THEN
#             SET review_found = TRUE
#         END IF
#     END FOR
#
#     IF user_found AND review_found THEN
#         SET count = 1
#         FOR i = 0 TO num_review - 1 DO
#             IF review_user_id[i] == input_user_id THEN
#                 SET username = CALL findUsername(review_user_id[i], num_user)
#                 DISPLAY "User Review", count
#                 DISPLAY review_user_id[i], username, review_rating[i], review_hotel_name[i], review_statement[i]
#                 SET count = count + 1
#             END IF
#         END FOR
#     ELSE
#         DISPLAY "User not found or has no reviews."
#     END IF
# END FUNCTION
#
# FUNCTION displaySpecificHotelReview(hotel_choice, num_hotel, num_review, num_user)
#     SET target_hotel = hotel_name[hotel_choice]
#     SET review_found = FALSE
#
#     FOR i = 0 TO num_review - 1 DO
#         IF review_hotel_name[i] == target_hotel THEN
#             SET review_found = TRUE
#             SET username = CALL findUsername(review_user_id[i], num_user)
#             DISPLAY "Review for", target_hotel
#             DISPLAY username, review_rating[i], review_statement[i]
#         END IF
#     END FOR
#
#     IF review_found == FALSE THEN
#         DISPLAY "No reviews found for this hotel."
#     END IF
# END FUNCTION
#
# FUNCTION displayHighRatingReview(hotel_choice, num_hotel, num_review, num_user)
#     SET target_hotel = hotel_name[hotel_choice]
#     SET review_found = FALSE
#
#     FOR i = 0 TO num_review - 1 DO
#         IF review_hotel_name[i] == target_hotel AND review_rating[i] >= 4 THEN
#             SET review_found = TRUE
#             SET username = CALL findUsername(review_user_id[i], num_user)
#             DISPLAY "High Rating Review for", target_hotel
#             DISPLAY username, review_rating[i], review_statement[i]
#         END IF
#     END FOR
#
#     IF review_found == FALSE THEN
#         DISPLAY "No positive reviews (4-5 stars) found for this hotel."
#     END IF
# END FUNCTION
#
# FUNCTION displayUserLatestInfo(num_user)
#     DISPLAY "User Profile Table Header"
#     FOR i = 0 TO num_user - 1 DO
#         DISPLAY user_id[i], user_name[i], country[i], state[i], email[i], membership_category[i], current_points[i]
#     END FOR
# END FUNCTION
#
# FUNCTION displaySummaryActivities(num_user, num_review, total_points)
#     DISPLAY "Total Number of Users:", num_user
#     DISPLAY "Total Number of Reviews:", num_review
#     DISPLAY "Total Points Awarded:", total_points
# END FUNCTION
#
# FUNCTION searchReviewByWord(num_review, num_user, keyword)
#     FOR i = 0 TO num_review - 1 DO
#         SET statement = TO_LOWER(review_statement[i])
#         SET search_key = TO_LOWER(keyword)
#         IF statement CONTAINS search_key THEN
#             SET username = CALL findUsername(review_user_id[i], num_user)
#             DISPLAY "Review Found:", review_user_id[i], username, review_rating[i], review_statement[i]
#         END IF
#     END FOR
# END FUNCTION
#
# FUNCTION findUsername(target_id, num_user)
#     FOR i = 0 TO num_user - 1 DO
#         IF user_id[i] == target_id THEN
#             username = user_name[i]
#             BREAK
#         END IF
#     END FOR
#     RETURN username
# END FUNCTION
#
# FUNCTION toLower(text)
#     CONVERT all characters in text to lowercase
#     RETURN text
# END FUNCTION

# %% [markdown]
# ##Flowchart

# %% [markdown]
# Please review the flowchart for TravelGo Hotel Review System uploaded to [Google Drive](https://drive.google.com/file/d/12I01NeQZAJxTRMdwiHvo51dYW2_3b_KG/view?usp=sharing).
#
# The original file can be viewed using [drawio](https://drive.google.com/file/d/1ba94R5bhaM9oM6wo4UrZ_zXfejLhm6yd/view?usp=sharing).

# %% [markdown]
# **Screenshot of the part of flowchart**
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Input Files

# %% [markdown]
# Executing this code will create a users list named "users.txt" within the Google Colab notebook environment.

# %%
# %%writefile users.txt
# U001	Alice Morgan	Orange	California	alice.morgan@yahoo.com	Gold	9900
# U002	Brian Chen	King	Washington	brian.chen@aol.com	Silver	3600
# U003	Sandra Lee	Clark	Nevada	sandra.lee@yahoo.com	Platinum	13250
# U004	Darren Low	Penang	Penang	darren.low@botmail.com	Silver	4300
# U005	Nur Aisha	Sepang	Selangor	aisha.nur@hotmail.com	Gold	8000
# U006	Hiro Tanaka	Osaka	Kansai	hiro.tanaka@mail.com	Silver	2600
# U007	Maria Gutierrez	Travis	Texas	m.gutierrez@example.com	Platinum	15900
# U008	John Peterson	Cook	Illinois	john.p@hotmail.com	Gold	6200
# U009	Lim Wei Jian	Johor Bahru	Johor	wj.lim@example.com	Silver	3100
# U010	Kavita Sharma	Mumbai	Maharashtra	kavita.sharma@yahoo.com	Gold	7600
# U011	Fiona Khalid	Gombak	Selangor	fiona.khalid@example.com	Silver	2400
# U012	Owen Riley	Maricopa	Arizona	owen.r@exhotmailample.com	Gold	5900
# U013	Chen Mei Lin	Tainan	Taiwan	meilin.chen@example.com	Silver	2700
# U014	James Walker	Miami-Dade	Florida	j.walker@aol.com	Platinum	11000
# U015	Siti Farah	Kota Kinabalu	Sabah	farah.s@example.com	Silver	2200
# U016	Carlos Ruiz	San Diego	California	carlos.r@yahoo.com	Gold	6600
# U017	Emily Johnson	Fulton	Georgia	emily.j@example.com	Silver	3550
# U018	Rahul Nair	Ernakulam	Kerala	rahul.nair@gmail.com	Gold	7700
# U019	Tan Jing Yi	Seremban	Negeri Sembilan	jingyi.tan@aol.com	Silver	2900
# U020	Adrian Yong	Kuching	Sarawak	adrian.y@aol.com	Platinum	14000
# Out:
# Overwriting users.txt

# %% [markdown]
# Executing this code will create a hotel review list named "review.txt" within the Google Colab notebook environment.

# %%
# %%writefile review.txt
# U001	5	Great service and clean room	Sunrise Hotel
# U002	3	Average, nothing special	Maple Stay
# U002	4	Comfortable and quiet	Royal Palace
# U004	5	Staff very friendly	Ocean Dream Resort
# U005	2	Room too small	Sunrise Hotel
# U006	5	Excellent food	Hotel Sakura
# U007	4	Nice pool and gym	Grand Imperial
# U008	1	Bad experience with staff	CityView Hotel
# U009	3	Quite okay	Ocean Dream Resort
# U010	5	Loved the ambience	Lotus Bay Resort
# U011	4	Good for short stays	CityView Hotel
# U012	3	Fair price and fair quality	Maple Stay
# U013	2	Aircond noisy	Hotel Sakura
# U014	5	Perfect holiday	Royal Palace
# U015	4	Spacious lobby	Lotus Bay Resort
# U016	3	Breakfast average	Grand Imperial
# U017	5	Very satisfied	Sunrise Hotel
# U018	4	Clean and modern	CityView Hotel
# U019	3	Acceptable	Maple Stay
# U020	5	Top-notch luxury	Royal Palace
# Out:
# Overwriting review.txt

# %% [markdown]
# ##The Code

# %% [markdown]
# The program's implementation is provided in the following code snippet.

# %%
# %%writefile travelgo.cpp
#
# # include <iostream>
# # include <iomanip>
# # include <fstream>
# # include <string>
# # include <algorithm>
#
# using namespace std;
#
# // Declare constant global variables
# const int MAX_USERS = 100;
# const int MAX_REVIEWS = 100;
#
# // Create function to read users.txt
# int readUsers(string user_id[], string user_name[], string country[], string state[],
#     string email[], string membership_category[], int current_points[]){
#
#     // Create input file stream object named readUserFile to read users.txt
#     ifstream readUserFile;
#     readUserFile.open("users.txt");
#
#     // Display appropriate message if the file fails to be opened
#     if (readUserFile.fail()){
#         cout << "\033[1;91m" << "users.txt failed to be open!" << "\033[0m"; // Display message in red colour and reset it at the end
#     }
#
#     // Initialize a variable to be used to count the number of user in the users.txt
#     int count = 0;
#
#     // Create loop to read data from users.txt into array
#     while (count < MAX_USERS && getline(readUserFile, user_id[count], '\t')) {
#
#         getline(readUserFile, user_name[count], '\t');
#         getline(readUserFile, country[count], '\t');
#         getline(readUserFile, state[count], '\t');
#         getline(readUserFile, email[count], '\t');
#         getline(readUserFile, membership_category[count], '\t');
#
#         readUserFile >> current_points[count];
#         readUserFile.ignore(); // flush the buffer
#
#         count++; // Update number of user after every loop
#     }
#
#     readUserFile.close(); // Close the input file stream object after all data is read into the array
#     return count; // Return the number of user to main
# }
#
# // Create function to read review.txt
# int readReview(string review_user_id[], int review_rating[], string review_statement[], string review_hotel_name[]){
#
#     // Create a input file stream object named readReviewFile to read review.txt
#     ifstream readReviewFile;
#     readReviewFile.open("review.txt");
#
#      // Display appropriate message if the file fails to be opened
#     if (readReviewFile.fail()){
#         cout << "\033[1;91m" << "review.txt failed to be open!" << "\033[0m"; // Display message in red colour and reset it at the end
#     }
#
#     // Initialize a variable to be used to count the number of review in the review.txt
#     int count_review = 0;
#     string temp_review_rating;
#
#     // Create loop to read data from review.txt into array
#     while( count_review < MAX_REVIEWS && getline(readReviewFile, review_user_id[count_review], '\t')){
#
#         getline(readReviewFile, temp_review_rating, '\t'); // Read rating as string first
#         review_rating[count_review] = stoi(temp_review_rating); // Convert the rating from string to int
#         getline(readReviewFile, review_statement[count_review], '\t');
#         getline(readReviewFile, review_hotel_name[count_review]);
#
#         count_review++; // Update the number of review
#     }
#
#     readReviewFile.close(); // Close the input file stream object after all data is read into the array
#     return count_review; // Return the number of review to main
# }
#
# // Create function to count number of word of each review
# void calculateNumWordReviewStatement(string review_statement[], int number_word_review_statement[], int num_review){
#
#     string text;
#
#     // Create a nested loop to count the number of word
#     for (int i=0; i<num_review; i++){
#
#         int count = 1; // Restore the number of word after every loop
#         text = review_statement[i];
#
#         // Loop to read text
#         for (char temp: text){
#
#             if(temp == ' '){
#                 count++;
#             }
#         }
#
#         number_word_review_statement[i] = count;
#     }
# }
#
# // Create function to recalculate points
# int recalculatePoints(string user_id[], string review_user_id[], int current_points[], int number_word_review_statement[], int num_user,
#     int num_review){
#
#     int total_points_awarded = 0;
#
#     // Create nested loop to add points based on number of review made
#     for (int i=0; i<num_user; i++){
#
#         // Declare variables used to calculate latest points based on number of review made by the user
#         // Restore variables after every loop
#         int count_review= 0;
#         int count_review_more_than_50_words = 0;
#
#         for(int j=0; j<num_review; j++){
#
#             if(review_user_id[j] == user_id[i]){
#
#                 count_review++; // Update number of review
#
#                 if(number_word_review_statement[j] > 50){
#
#                     count_review_more_than_50_words += (number_word_review_statement[j] / 50) ; // Update number of review that has more than 50 words
#                 }
#             }
#         }
#
#         current_points[i] += ((count_review * 100) + (count_review_more_than_50_words * 10)); // Update current points based on number of review
#         total_points_awarded += ((count_review * 100) + (count_review_more_than_50_words * 10)); // Calculate total points awarded
#     }
#
#     return total_points_awarded;
# }
#
# // Create function to update membership category
# void updateMembershipCategory(string user_id[], string membership_category[], int current_points[], int num_user, string copy_membership_category[], string username[]){
#
#     // Initialize boolean status for membership category upgrade status
#     bool membership_update = false;
#
#     // Update membership category based on the updated points
#     for (int i=0; i<num_user; i++){
#
#         if (current_points[i] < 1000){
#             membership_category[i] = "Basic";
#         }
#         else if(current_points[i] >= 1000 && current_points[i] <= 4999){
#             membership_category[i] = "Silver";
#         }
#         else if(current_points[i] >= 5000 && current_points[i] <= 9999){
#             membership_category[i] = "Gold";
#         }
#         else{
#             membership_category[i] = "Platinum";
#         }
#
#         // Check whether there is an upgrade of membership category for any user
#         if(membership_category[i] != copy_membership_category[i]){
#             membership_update = true;
#         }
#     }
#
#     // Display message when a user change from one category to another
#     if (membership_update == true){
#
#         cout << "\033[1;96m\n============================= Membership Upgrades ===============================\033[0m" << endl << endl; // Display text in cyan colour and reset it to default at the end
#
#         cout << "\033[1;93m"; // Display header in yellow colour and reset it to default at the end
#         cout << left
#         << "|" << setw(10) << "UserID"
#         << "|" << setw(20) << "Username"
#         << "|" << setw(15) << "Old Category"
#         << "|" << setw(15) << "New Category"
#         << "|" << setw(15) << "Current Points" << "|"
#         << endl;
#
#         // Display Horizontal Line
#         cout << "+"
#         << string(10, '-')   << "+"
#         << string(20, '-')   << "+"
#         << string(15, '-')   << "+"
#         << string(15, '-')   << "+"
#         << string(15, '-')   << "+\n";
#         cout << "\033[0m";
#
#
#         for (int i = 0; i < num_user; i++) {
#
#             if (membership_category[i] != copy_membership_category[i]) {
#
#                 // Display the vertical and horizontal line in yellow colour while the colour of text remain as default
#                 cout << left
#                 << "\033[1;93m|\033[0m" << setw(10) << user_id[i]
#                 << "\033[1;93m|\033[0m" << setw(20) << username[i]
#                 << "\033[1;93m|\033[0m" << setw(15) << copy_membership_category[i]
#                 << "\033[1;93m|\033[0m" << setw(15) << membership_category[i]
#                 << "\033[1;93m|\033[0m" << setw(15) << current_points[i] << "\033[1;93m|\033[0m"
#                 << endl;
#
#                 // Print horizontal line in yellow colour and reset it to default at the end
#                 cout << "\033[1;93m";
#                 cout << "+"
#                 << string(10, '-')   << "+"
#                 << string(20, '-')   << "+"
#                 << string(15, '-')   << "+"
#                 << string(15, '-')   << "+"
#                 << string(15, '-')   << "+\n";
#                 cout << "\033[0m";
#             }
#         }
#     }
#
# }
#
# // Create function to calculate number of hotel and Record name of hotel uniquely
# int calculateNumHotel(string review_hotel_name[], int num_review, string hotel_name[]){
#
#     // Initialize number of hotel
#     int number_hotel = 0;
#
#     for (int i=0; i<num_review; i++){
#
#         // Initialize and restore boolean status after every loop
#         bool found_status = false;
#
#         for (int j=0; j<number_hotel; j++){
#
#             if(hotel_name[j] == review_hotel_name[i]){
#
#                 found_status = true;
#                 break;
#
#             }
#         }
#
#         // Store new hotel name when there is a new hotel name found
#         if (found_status == false){
#
#             hotel_name[number_hotel] = review_hotel_name[i];
#             number_hotel++;
#
#         }
#
#     }
#
#     return number_hotel;
# }
#
# // Create function to calculate number of review made on a hotel and total rating of a hotel
# void calculateNumReviewHotel(string review_hotel_name[], int review_rating[], int num_review, int number_hotel, string hotel_name[],
#     int number_review_hotel[], int total_rating_hotel[]){
#
#     for (int i=0; i<number_hotel; i++){
#
#         number_review_hotel[i] = 0;
#         total_rating_hotel[i] = 0;
#
#         for (int j=0; j<num_review; j++){
#
#             if (review_hotel_name[j] == hotel_name[i]){
#
#                 number_review_hotel[i]++;
#                 total_rating_hotel[i] += review_rating[j];
#
#             }
#         }
#     }
# }
#
# // Create function to find username based on review user id
# string findUsername(int num_user, string user_name[], string review_user_id, string user_id[], string username){
#
#     for (int i=0; i<num_user; i++){
#
#         if (review_user_id == user_id[i]){
#             username = user_name[i];
#             break;
#         }
#     }
#
#     return username;
# }
#
# // Create function to display review made by a specific user
# void displaySpecificUserReview(string user_id[], string user_name[], string review_user_id[], int review_rating[],
#     string review_statement[],string review_hotel_name[], string input_user_id, int num_review, int num_user, int choice){
#
#     bool review_status = false;
#     bool user_status = false;
#
#     // Loop to determine whether the entered userID is in the user list or not
#     for (int i=0; i<num_user; i++){
#
#         if (input_user_id == user_id[i]){
#             user_status = true;
#         }
#
#         for (int j=0; j<num_review; j++){
#
#             if (input_user_id == review_user_id[j]){
#                 review_status = true;
#             }
#         }
#     }
#
#     if (user_status == true && review_status == true){
#
#         string username = " "; // Initialize username
#         int count = 1;
#
#         // Loop to find the review based on review user id
#         for (int i=0 ; i< num_review; i++){
#
#
#             if (input_user_id == review_user_id[i]){
#
#                 // Call function to find username based on review id
#                 username = findUsername(num_user, user_name, review_user_id[i], user_id, username);
#
#                  // Display header in cyan and reset it to default at the end
#                 cout << "\033[1;96m"<< "\n================================\n";
#                 cout << "         User Review " << count << endl;
#                 cout << "================================\n" << "\033[0m";
#
#                 // Display user and review details
#                 cout << left;
#                 cout << setw(15) << "User ID" << ": " << review_user_id[i] << endl;
#                 cout << setw(15) << "Username" << ": " << username << endl;
#                 cout << setw(15) << "Rating" << ": "<< review_rating[i] << "/5\n";
#                 cout << setw(15) << "Hotel Name" << ": " << review_hotel_name[i] << endl;
#                 cout << setw(15) << "Statement" << ": " << review_statement[i] << endl;
#                 count++;
#             }
#         }
#     }
#
#     // Display appropriate message when the user is not found
#     if (user_status == false){
#         cout << "\033[1;91m" << "User not found!\n" << "\033[0m";  // Display message in red color and reset it to default at the end
#     }
#     else{
#         // Display appropriate message when no review is made by the user
#         if (review_status == false){
#             cout << "\033[1;91m" << "This user doesn't make any review.\n" << "\033[0m"; // Display message in red color and reset it to default at the end
#         }
#     }
# }
#
# // Create function to display review for a specific hotel
# void displaySpecificHotelReview(int hotel_choice, string review_hotel_name[], string review_user_id[], int review_rating[],
#     string review_statement[], string user_name[], string user_id[], int number_review, int num_user, int number_hotel, string hotel_name[]){
#
#     bool review_status = false;
#     bool hotel_status = false;
#
#     for (int i=0; i<number_review; i++){
#
#         for (int j=0; j<number_hotel; j++){
#
#             // Check the validity of hotel
#             if (hotel_name[hotel_choice] == hotel_name[j]){
#                 hotel_status = true;
#             }
#         }
#
#         // Check whether there is a review made to this hotel
#         if (hotel_name[hotel_choice] == review_hotel_name[i]){
#             review_status = true;
#         }
#     }
#
#     if (review_status == true && hotel_status == true){
#
#         string username = " "; // Initialize username
#
#         int count = 1;
#
#         // Create loop to display the review of a specific hotel
#         for (int i=0 ;i<number_review; i++){
#
#
#             if (hotel_name[hotel_choice] == review_hotel_name[i]){
#
#                 // Call function to find username based on review user id
#                 username = findUsername(num_user, user_name, review_user_id[i], user_id, username);
#
#                 // Display Header in cyan and reset it to default at the end
#                 cout << "\033[1;96m"<< "\n================================\n";
#                 cout << "         Hotel Review " << count << endl;
#                 cout << "================================\n" << "\033[0m";
#
#                 cout << left;
#                 cout << setw(15) << "User ID" << ": " << review_user_id[i] << endl;
#                 cout << setw(15) << "Username" << ": " << username << endl;
#                 cout << setw(15) << "Rating" << ": "<< review_rating[i] << "/5\n";
#                 cout << setw(15) << "Statement" << ": " << review_statement[i] << endl;
#                 count++;
#
#                 review_status = true;
#             }
#         }
#     }
#
#     // Display appropriate message when the input hotel name is not in the list of hotel
#     if (hotel_status == false){
#         cout << "\033[1;91m" << "\nHotel not found! Please use the hotel listed above!\n" << "\033[0m" ; // Display message in red color and reset it to default at the end
#     }
#     else{
#         if(review_status == false){
#             cout << "\033[1;91m" << "\nNo review is made to this hotel!\n" << "\033[0m"; // Display message in red color and reset it to default at the end
#         }
#     }
# }
#
# // Create function to display the latest user information
# void displayUserLatestInfo(string user_id[], string user_name[], string country[], string state[], string email[], string membership_category[],
#     int current_points[] , int num_user){
#
#     // Display header in blue colour
#     cout << "\033[1;94m";
#     cout << left
#     << "|" << setw(10) << "UserID"
#     << "|" << setw(20) <<"Username"
#     << "|" << setw(15) << "Country"
#     << "|" << setw(18) << "State"
#     << "|" << setw(30) << "Email Address"
#     << "|" << setw(25) << "Membership Category"
#     << "|" << setw(15) << "Current Points" << "|"
#     << endl;
#
#     // Display Horizontal Line in blue colour
#     cout << "+"
#     << string(10, '-')   << "+"
#     << string(20, '-')   << "+"
#     << string(15, '-')   << "+"
#     << string(18, '-')   << "+"
#     << string(30, '-')   << "+"
#     << string(25, '-')   << "+"
#     << string(15, '-')   << "+\n";
#     cout << "\033[0m"; // Reset colour to default
#
#     // Create loop to display the latest user information
#     for (int i=0; i<num_user; i++){
#
#         // Display horizontal lines and user details
#         cout << left
#         << "\033[1;94m|\033[0m" << setw(10) << user_id[i]
#         << "\033[1;94m|\033[0m" << setw(20) << user_name[i]
#         << "\033[1;94m|\033[0m" << setw(15) << country[i]
#         << "\033[1;94m|\033[0m" << setw(18) << state[i]
#         << "\033[1;94m|\033[0m" << setw(30) << email[i]
#         << "\033[1;94m|\033[0m" << setw(25) << membership_category[i]
#         << "\033[1;94m|\033[0m" << setw(15) << current_points[i] << "\033[1;94m|\033[0m"
#         << endl;
#
#         // Display horizontal line in blue colour
#         cout << "\033[1;94m";
#         cout << "+"
#         << string(10, '-')   << "+"
#         << string(20, '-')   << "+"
#         << string(15, '-')   << "+"
#         << string(18, '-')   << "+"
#         << string(30, '-')   << "+"
#         << string(25, '-')   << "+"
#         << string(15, '-')   << "+\n";
#         cout << "\033[0m"; // Reset colour to default
#     }
# }
#
# // Create function to display review of high rating 4 or 5 for specific hotel
# void displayHighRatingReview(int hotel_choice, string review_hotel_name[], string review_user_id[], int review_rating[], string review_statement[],
#     string user_id[], string user_name[], int num_user, int number_review, int number_hotel, string hotel_name[]){
#
#     bool review_status = false;
#     bool hotel_status = false;
#
#     for (int i=0; i<number_review; i++){
#
#         for (int j=0; j<number_hotel; j++){
#
#             // Check the validity of hotel
#             if (hotel_name[hotel_choice] == hotel_name[j]){
#                 hotel_status = true;
#             }
#         }
#
#         // Check whether there is a review made to this hotel
#         if (hotel_name[hotel_choice] == review_hotel_name[i]){
#
#             if (review_rating[i] >= 4){
#
#             review_status = true;
#
#             }
#         }
#     }
#
#     if (review_status == true){
#
#         string username = " "; // Initialize username
#         int count = 1;
#
#         // Create loop to display review of a specific hotel
#         for (int i=0; i<number_review; i++){
#
#             if(hotel_name[hotel_choice] == review_hotel_name[i]){
#
#                 if (review_rating[i] >= 4){
#
#                     // Call function to find username based on review user id
#                     username = findUsername(num_user, user_name, review_user_id[i], user_id, username);
#
#                     // Display header in cyan and reset it to default at the end
#                     cout << "\033[1;96m"<< "\n================================\n";
#                     cout << "         Hotel Review " << count << endl;
#                     cout << "================================\n" << "\033[0m";
#
#                     cout << left;
#                     cout << setw(15) << "User ID" << ": " << review_user_id[i] << endl;
#                     cout << setw(15) << "Username" << ": " << username << endl;
#                     cout << setw(15) << "Rating" << ": "<< review_rating[i] << "/5\n";
#                     cout << setw(15) << "Statement" << ": " << review_statement[i] << endl;
#                     count++;
#                 }
#             }
#         }
#     }
#
#     // Display appropriate message when the input hotel name is not in the list of hotel
#     if (hotel_status == false){
#         cout << "\033[1;91m" << "\nHotel not found! Please use the hotel listed above!\n" << "\033[0m" ; // Display message in red color and reset it to default at the end
#     }
#     // Display appropriate message if there is no review with rating 4 or 5 for this hotel
#     else if (review_status == false){
#         cout << "\033[1;91m\nThere is no high rating review for " << hotel_name[hotel_choice] << ".\033[0m"; // Display message in red colour and reset it to default at the end
#     }
# }
#
# // Create function to display summary of activities
# void displaySummaryActivities(int num_user, int num_review, int total_points_awarded){
#     cout << left;
#     cout << "\033[1;33m" << setw(35) << "Total number of users" << ": " << "\033[0m" << num_user << endl; // Display text in yellow colour and reset it to default at the end
#     cout << "\033[1;33m" << setw(35) << "Total number of reviews" << ": " << "\033[0m" << num_review << endl; // Display text in yellow colour and reset it to default at the end
#     cout << "\033[1;33m" << setw(35) << "Total points awarded system-wide" << ": " << "\033[0m" << total_points_awarded << endl; // Display text in yellow colour and reset it to default at the end
# }
#
# // Create function that used for display specific membership category members
# void innerDisplayUsersByMembership(string user_id[], string user_name[], string membership_category[], int current_points[], int num_user, string target_category){
#
#     bool membership_status = false;
#
#     for (int i=0 ;i<num_user; i++){
#
#         if (membership_category[i] == target_category){
#             membership_status = true;
#         }
#     }
#
#     if (membership_status == true){
#         // Display Header in Cyan & Blue
#         cout << endl << "\033[1;96m" << target_category << " Member\n\033[0m";
#         cout << "\033[1;94m";
#         cout << left
#         << "|" <<setw(10) << "UserID"
#         << "|" << setw(20) << "Username"
#         << "|" << setw(15) << "Current Points" << "|"
#         << endl;
#
#         // Print horizontal line in blue colour
#         cout << "+"
#         << string(10, '-')   << "+"
#         << string(20, '-')   << "+"
#         << string(15, '-')   << "+\n";
#         cout << "\033[0m"; // Reset colour to default
#
#         // Loop to find target category member
#         for (int i=0; i<num_user; i++){
#
#             if (membership_category[i] == target_category){
#                 cout << left
#                 << "\033[1;94m|\033[0m" << setw(10) << user_id[i]
#                 << "\033[1;94m|\033[0m" << setw(20) << user_name[i]
#                 << "\033[1;94m|\033[0m" << setw(15) << current_points[i] << "\033[1;94m|\033[0m"
#                 << endl;
#
#                 // Print horizontal line in blue colour
#                 cout << "\033[1;94m";
#                 cout << "+"
#                 << string(10, '-')   << "+"
#                 << string(20, '-')   << "+"
#                 << string(15, '-')   << "+\n";
#                 cout << "\033[0m"; // Reset colour to default
#             }
#         }
#     }
#     // Display appropriate message when there is no member in this category
#     else{
#         cout << endl << "\033[1;96m" << target_category << " Member\n\033[0m";
#         cout << "\033[1;91m" << "|      No users found in this category.         |\n" << "\033[0m"; // Dispaly message in red colour and reset it to default at the end
#     }
# }
#
# // Create function to display users grouped by membership category
# void displayUsersByMembership(string user_id[], string user_name[], string membership_category[], int current_points[], int num_user){
#
#     int choice;
#     double choice_double;
#     bool choice_status = false;
#
#     while(choice_status == false){ // Input Data Validation
#         cout << "\033[1;95m" << "\n===========================\n" << "\033[0m";  // Display text in purple and restore it at the end
#         cout << "\033[1;94m" << "   Sorting Features Menu\n" << "\033[0m";     // Display text in blue and restore it at the end
#         cout << "\033[1;95m" << "===========================\n" << "\033[0m";
#         cout << "\033[1;94m" << "1. Ascending Order\n2. Descending Order\n" << "\033[0m";
#         cout << "\nEnter your choice: ";
#         cin >> choice_double; // Read the entered value as double to make the choice always an int
#         cin.ignore(); // flush the buffer
#         choice = choice_double; // Convert the choice from double to int
#
#         if (choice == 1 || choice == 2){
#             choice_status = true;
#         }
#         else{
#             cout << "\033[1;91m" << "\nInvalid Choice! Please make input again!\n";
#         }
#     }
#
#     // Sort users in ascending order
#     if (choice == 1){
#         for (int i=0;i<num_user -1; i++){
#             for (int j=i+1; j<num_user; j++){
#                 if (current_points[j] < current_points[i]){
#                     swap(user_id[j], user_id[i]);
#                     swap(user_name[j], user_name[i]);
#                     swap(current_points[j], current_points[i]);
#                     swap(membership_category[j], membership_category[i]);
#                 }
#             }
#         }
#     }
#     // Sort users in descending order
#     else if (choice == 2){
#         for (int i=0; i<num_user -1; i++){
#             for (int j=i+1; j<num_user; j++){
#                 if (current_points[j] > current_points[i]){
#
#                     swap(user_id[j], user_id[i]);
#                     swap(user_name[j], user_name[i]);
#                     swap(current_points[j], current_points[i]);
#                     swap(membership_category[j], membership_category[i]);
#                 }
#             }
#         }
#     }
#
#
#     // Call function to display platinum member
#     innerDisplayUsersByMembership(user_id, user_name, membership_category, current_points, num_user, "Platinum");
#
#     // Call function to display Gold member
#     innerDisplayUsersByMembership(user_id, user_name, membership_category, current_points, num_user, "Gold");
#
#     // Call function to display Silver member
#     innerDisplayUsersByMembership(user_id, user_name, membership_category, current_points, num_user, "Silver");
#
#     // Call function to display Basic member
#     innerDisplayUsersByMembership(user_id, user_name, membership_category, current_points, num_user, "Basic");
#
# }
#
# // Create function to sort users based on number of review
# void sortUsersNumReview(int num_user, int count_review[], string user_id[], string user_name[]){
#
#     // Create nested loop to sort the user into descending order based on the number of review made
#     for (int i=0; i<num_user - 1; i++){
#
#         for (int j=i+1 ; j<num_user; j++){
#
#             if (count_review[j] > count_review[i]){
#
#                 // Swap position of array
#                 swap(user_id[j], user_id[i]);
#                 swap(user_name[j], user_name[i]);
#                 swap(count_review[j], count_review[i]);
#             }
#
#         }
#     }
# }
#
# // Create function to display top reviewer leaderboard
# void displayTopReviewerLeaderboard(int num_user, int count_review[], string user_id[], string user_name[], int current_points[]){
#
#     // Display Header in Blue
#     cout << "\033[1;94m";
#     cout << left
#     << "|" << setw(10) << "Rankings"
#     << "|" << setw(10) << "UserID"
#     << "|" << setw(20) << "Username"
#     << "|" << setw(22) << "Number of Review Made" << "|"
#     << endl;
#
#     // Print horizontal line
#     cout << "+"
#     << string(10, '-')   << "+"
#     << string(10, '-')   << "+"
#     << string(20, '-')   << "+"
#     << string(22, '-')   << "+\n";
#     cout << "\033[0m"; // Reset colour to default
#
#     for (int i=0; i<num_user; i++){
#
#         // Calculate number of review of each user based on their current points and assume all review is not more than 50 words
#         count_review[i] = current_points[i] / 100;
#     }
#
#
#     // Call Function to arrange users in descending order based on the number of review
#     sortUsersNumReview(num_user, count_review, user_id, user_name);
#
#     // Initialize rank
#     int rank = 1;
#
#     // Display user information based on their rankings
#     for (int i=0; i<num_user; i++){
#
#         // if same count as previous → same rank
#         if (i > 0 && count_review[i] == count_review[i - 1]) {
#             // rank stays the same
#         }
#         else {
#             // new rank = current index + 1
#             rank = i + 1;
#         }
#
#         // Display details
#         cout << left
#         << "\033[1;94m|\033[0m" << setw(10) << rank
#         << "\033[1;94m|\033[0m" << setw(10) << user_id[i]
#         << "\033[1;94m|\033[0m" << setw(20) << user_name[i]
#         << "\033[1;94m|\033[0m" << setw(22) << count_review[i] << "\033[1;94m|\033[0m"
#         << endl;
#
#         // Print horizontal line
#         cout << "\033[1;94m";
#         cout << "+"
#         << string(10, '-')   << "+"
#         << string(10, '-')   << "+"
#         << string(20, '-')   << "+"
#         << string(22, '-')   << "+\n";
#         cout << "\033[0m"; // Reset Colour to default
#     }
#
# }
#
# // Create function to display top 3 users with most reviews
# void displayTop3Reviewer(int num_user, int count_review[], string user_id[], string user_name[], int current_points[]){
#
#     for (int i=0; i<num_user; i++){
#
#         // Calculate number of review of each user based on their current points and assume all review is not more than 50 words
#         count_review[i] = current_points[i] / 100;
#     }
#
#     // Display Header in blue
#     cout << "\033[1;94m";
#     cout << left
#     << "|" << setw(10) << "Rankings"
#     << "|" << setw(10) << "UserID"
#     << "|" << setw(20) << "Username"
#     << "|" << setw(22) << "Number of Review Made" << "|"
#     << endl;
#
#     // Print horizontal line
#     cout << "+"
#     << string(10, '-')   << "+"
#     << string(10, '-')   << "+"
#     << string(20, '-')   << "+"
#     << string(22, '-')   << "+\n";
#     cout << "\033[0m"; // Reset Colour to default
#
#     // Call Function to arrange users in descending order
#    sortUsersNumReview(num_user, count_review, user_id, user_name);
#
#     // Initialize rank
#     int rank = 1;
#
#     for (int i=0; i<num_user; i++){
#
#         // if same count as previous → same rank
#         if (i > 0 && count_review[i] == count_review[i - 1]) {
#             // rank stays the same
#         }
#         else {
#             // new rank = current index + 1
#             rank = i + 1;
#         }
#
#         if (rank <= 3){
#             // Display details
#             cout << left
#             << "\033[1;94m|\033[0m" << setw(10) << rank
#             << "\033[1;94m|\033[0m" << setw(10) << user_id[i]
#             << "\033[1;94m|\033[0m" << setw(20) << user_name[i]
#             << "\033[1;94m|\033[0m" << setw(22) << count_review[i] << "\033[1;94m|\033[0m"
#             << endl;
#
#             // Print horizontal line
#             cout << "\033[1;94m";
#             cout << "+"
#             << string(10, '-')   << "+"
#             << string(10, '-')   << "+"
#             << string(20, '-')   << "+"
#             << string(22, '-')   << "+\n";
#             cout << "\033[0m"; // Reset Colour to default
#         }
#     }
# }
#
# // Create function to display hotel rating summary
# void displayHotelRatingSummary(int num_hotel, string hotel_name[], int number_review_hotel[], int total_rating_hotel[]){
#
#     int choice, choice_sort;
#     double choice_sort_by;
#     bool choice_status = false, choice_sort_status = false;
#
#     while(choice_status == false){ // Input Data Validation
#         cout << "\033[1;95m" << "\n===========================\n" << "\033[0m";             // Display text in purple and reset it to default at the end
#         cout << "\033[1;94m" << "   Sorting Features Menu\n" << "\033[0m";                  // Display text in blue and reset it to default at the end
#         cout << "\033[1;95m" << "===========================\n" << "\033[0m";               // Display text in purple and reset it to default at the end
#         cout << "\033[1;94m" << "1. Sort by Number of Review\n2. Sort by Rating\n" << "\033[0m";   // Display text in blue and reset it to default at the end
#         cout << "\nEnter your choice: ";
#         cin >> choice_sort_by; // Read the entered value as double to make the choice always an int
#         cin.ignore(); // flush the buffer
#         choice = choice_sort_by; // Convert the choice from double to int
#
#         if (choice == 1 || choice == 2){
#         choice_status = true;
#         }
#         else{
#             cout << "\033[1;91m" << "\nInvalid Choice! Please make input again!\n\033[0m"; // Display text in red colour and reset it to default at the end
#         }
#     }
#
#     while(choice_status == true && choice_sort_status == false){ // Input Data Validation
#         cout << "\033[1;95m" << "\n===========================\n" << "\033[0m";             // Display text in purple and reset it to default at the end
#         cout << "\033[1;94m" << "   Sorting Features Menu\n" << "\033[0m";                  // Display text in blue and reset it to default at the end
#         cout << "\033[1;95m" << "===========================\n" << "\033[0m";               // Display text in purple and reset it to default at the end
#         cout << "\033[1;94m" << "1. Ascending Order\n2. Descending Order\n" << "\033[0m";   // Display text in blue and reset it to default at the end
#         cout << "\nEnter your choice: ";
#         cin >> choice_sort_by; // Read the entered value as double to make the choice always an int
#         cin.ignore(); // flush the buffer
#         choice_sort = choice_sort_by; // Convert the choice from double to int
#
#         if (choice_sort == 1 || choice_sort == 2){
#         choice_sort_status = true;
#         }
#         else{
#             cout << "\033[1;91m" << "\nInvalid Choice! Please make input again!\n\033[0m"; // Display text in red colour and reset it to default at the end
#         }
#     }
#
#     // Sort hotel based on number of review
#     if (choice == 1){
#         // Sort hotel in ascending order
#         if (choice_sort == 1){
#             for (int i=0; i< num_hotel-1; i++){
#                 for (int j=i+1; j<num_hotel; j++){
#                     if (number_review_hotel[j] < number_review_hotel[i]){
#                         swap (hotel_name[j], hotel_name[i]);
#                         swap (number_review_hotel[j], number_review_hotel[i]);
#                         swap (total_rating_hotel[j], total_rating_hotel[i]);
#                     }
#                 }
#             }
#         }
#         // Sort hotel in descending order
#         else{
#             for (int i=0; i< num_hotel-1; i++){
#                 for (int j=i+1; j<num_hotel; j++){
#                     if (number_review_hotel[j] > number_review_hotel[i]){
#                         swap (hotel_name[j], hotel_name[i]);
#                         swap (number_review_hotel[j], number_review_hotel[i]);
#                         swap (total_rating_hotel[j], total_rating_hotel[i]);
#                     }
#                 }
#             }
#         }
#     }
#     // Sort hotel based on rating
#     else{
#         // Sort hotel in ascending order
#         if (choice_sort == 1){
#             for (int i=0; i< num_hotel-1; i++){
#                 for (int j=i+1; j<num_hotel; j++){
#                     if ((static_cast<double>(total_rating_hotel[j]) / static_cast<double>(number_review_hotel[j])) < (static_cast<double>(total_rating_hotel[i]) / static_cast<double>(number_review_hotel[i]))){
#                         swap (hotel_name[j], hotel_name[i]);
#                         swap (number_review_hotel[j], number_review_hotel[i]);
#                         swap (total_rating_hotel[j], total_rating_hotel[i]);
#                     }
#                 }
#             }
#         }
#         // Sort hotel in descending order
#         else{
#             for (int i=0; i< num_hotel-1; i++){
#                 for (int j=i+1; j<num_hotel; j++){
#                     if ((static_cast<double>(total_rating_hotel[j]) / static_cast<double>(number_review_hotel[j])) > (static_cast<double>(total_rating_hotel[i]) / static_cast<double>(number_review_hotel[i]))){
#                         swap (hotel_name[j], hotel_name[i]);
#                         swap (number_review_hotel[j], number_review_hotel[i]);
#                         swap (total_rating_hotel[j], total_rating_hotel[i]);
#                     }
#                 }
#             }
#         }
#     }
#
#
#
#
#     // Dislay Header in blue
#     cout << "\033[1;94m";
#     cout << endl;
#     cout << left
#     << "|" << setw(30) << "Hotel Name"
#     << "|" << setw(20) << "Average Rating"
#     << "|" << setw(20) << "Number of Review" << "|"
#     << endl;
#
#     // Print horizontal line
#     cout << "+"
#     << string(30, '-')   << "+"
#     << string(20, '-')   << "+"
#     << string(20, '-')   << "+\n";
#     cout << "\033[0m"; // Reset Colour to default
#
#     for (int i=0; i<num_hotel; i++){
#
#         double average_rating = static_cast<double>(total_rating_hotel[i]) / static_cast<double>(number_review_hotel[i]); // Calculate the average rating of hotel
#
#         // Display details
#         cout << left
#         << "\033[1;94m|\033[0m" << setw(30) << hotel_name[i]
#         << "\033[1;94m|\033[0m" << setw(20) << fixed << showpoint << setprecision(2) << average_rating
#         << "\033[1;94m|\033[0m" << setw(20) << number_review_hotel[i] << "\033[1;94m|\033[0m"
#         << endl;
#
#         // Print horizontal line in blue
#         cout << "\033[1;94m";
#         cout << "+"
#         << string(30, '-')   << "+"
#         << string(20, '-')   << "+"
#         << string(20, '-')   << "+\n";
#         cout << "\033[0m"; // Reset Colour to default
#     }
# }
#
# // Create function add new review and return new number of review
# int addNewReview(int num_review, int num_user, string review_user_id[], string user_id[], int current_points[], string review_hotel_name[],
#     string review_statement[], int review_rating[], string hotel_name[], int number_review_hotel[], int total_rating_hotel[]){
#
#     bool user_status = false;
#
#     // Declare input variables
#     string input_user_id;
#     string input_hotel_name;
#     string input_statement;
#     double input_rating;
#
#     cout << "Enter UserID: ";
#     cin >> input_user_id;
#     cin.ignore(); // Flush the buffer
#
#     // Determine whether the input user id exist in the user list
#     for (int i=0; i<num_user ; i++){
#
#         if (input_user_id == user_id[i]){
#             user_status = true;
#             break;
#         }
#     }
#
#     // Input Data Validation for UserID
#     while (user_status != true){
#         cout << "\033[1;91m" << "\nUser not found in the user list! Please make your input again!\n\n" << "\033[0m"; // Display message in red colour and reset it at the end
#         cout << "Enter UserID: ";
#         cin >> input_user_id;
#         cin.ignore(); // Clear the buffer
#
#         // Determine whether the input user id exist in the user list
#         for (int i=0; i<num_user ; i++){
#             if (input_user_id == user_id[i]){
#                 user_status = true;
#                 break;
#             }
#         }
#     }
#
#     cout << "Enter Hotel Name: ";
#     getline(cin, input_hotel_name);
#
#     cout << "Enter Review Statement: ";
#     getline(cin, input_statement);
#
#     // Read the rating as double first to make the rating always a int
#     cout << "Enter Rating (1-5): ";
#     cin >> input_rating;
#     cin.ignore(); // Flush the buffer
#
#     // Input Data Validation for Rating
#     while (input_rating < 1 || input_rating > 5){
#         cout << "\033[1;91m" << "\nInvalid Input for rating! Rating must be between 1 and 5.\n\n" << "\033[0m"; // Display message in red colours and reset it at the end
#         cout << "Enter Rating (1-5): ";
#         cin >> input_rating;
#         cin.ignore(); // Flush the buffer
#     }
#
#     // Read the entered data into array if the user is found in the user list
#     if (user_status == true){
#
#         review_user_id[num_review] = input_user_id;
#         review_hotel_name[num_review] = input_hotel_name;
#         review_statement[num_review] = input_statement;
#         review_rating[num_review] = input_rating; // change rating from double to int
#         num_review++;
#     }
#
#     int count = 1;
#
#     // Count the number of character for each review statement
#     for (char temp: input_statement){
#
#             if(temp == ' '){
#                 count++;
#             }
#
#     }
#
#     // Update current point and membership category
#     for (int i=0; i<num_user; i++){
#
#         if (input_user_id == user_id[i]){
#
#             // Update current points of the user once a new review is made
#             current_points[i] += 100;
#
#             if (count >= 50){
#                 current_points[i] += (count / 50) * 10;
#             }
#         }
#     }
#
#     // Call function to update the number of hotel and record if there is new hotel name
#     int number_hotel = calculateNumHotel(review_hotel_name, num_review, hotel_name);
#
#     // Call function to update number of review of each hotel
#     calculateNumReviewHotel(review_hotel_name, review_rating, num_review, number_hotel, hotel_name, number_review_hotel, total_rating_hotel);
#
#     return number_hotel;
# }
#
# // Create function to lowercase the input letter
# string toLower(string text){
#     transform(text.begin(),text.end(), text.begin(), :: tolower); // Convert the keyword to lowercase
#     return text;
# }
#
# // Create function to search review by text
# void searchReviewByWord(int num_review,int num_user, string keyword, string review_statement[], string user_id[], string review_user_id[],
#     string user_name[], string review_hotel_name[], int review_rating[]){
#
#     int count = 1;
#
#     for (int i=0; i<num_review; i++){
#
#         string username = " "; // Initialize username
#         string statement = toLower(review_statement[i]); // Call function to lowercase all the letter in review statement
#
#         if (statement.find(keyword) != string::npos){  // Check if the keyword exists in the review statement
#
#             // Call function to find username based on review id
#             username = findUsername(num_user, user_name, review_user_id[i], user_id, username);
#
#             // Display Header in cyan and reset colour to default at the end
#             cout << "\033[1;96m"<< "\n================================\n";
#             cout << "         User Review " << count << endl;
#             cout << "================================\n" << "\033[0m";
#
#             // Display details
#             cout << left;
#             cout << setw(15) << "User ID" << ": " << review_user_id[i] << endl;
#             cout << setw(15) << "Username" << ": " << username << endl;
#             cout << setw(15) << "Rating" << ": "<<review_rating[i] << "/5\n";
#             cout << setw(15) << "Hotel Name" << ": " << review_hotel_name[i] << endl;
#             cout << setw(15) << "Statement" << ": " << review_statement[i] << endl;
#             count++;
#         }
#     }
# }
#
# // Create function to update users.txt
# void updateUserFile(int num_user, string user_id[], string user_name[], string country[], string state[], string email[], string membership_category[], int current_points[]){
#
#     ofstream updateUserFile; // Create a output file stream object for users.txt
#     updateUserFile.open("users.txt"); // Open file to clear the existing data and input data to users.txt
#
#     // Update the latest user data into users.txt
#     for (int i=0; i<num_user; i++){
#
#         updateUserFile << user_id[i] << "\t"
#         << user_name[i] << "\t"
#         << country[i] << "\t"
#         << state[i] << "\t"
#         << email[i] << "\t"
#         << membership_category[i] << "\t"
#         << current_points[i] << endl;
#
#     }
#
#     // Display appropriate message to tell user whether data is saved to the file
#     if (updateUserFile.is_open()){
#         cout << "\033[1;93m" << "\nLatest user data have been successfully updated to users.txt!" << "\033[0m"; // Display message in yellow and reset it at the end
#     }
#     else{
#         cout << "\033[1;91m" << "\nData fails to be updated to users.txt!" << "\033[0m"; // Display message in red and reset it at the end
#     }
#
#     // Close the output file stream object after update data into the file
#     updateUserFile.close();
# }
#
# // Create function to update review.txt
# void updateReviewFile(int num_review, string review_user_id[], int review_rating[], string review_statement[], string review_hotel_name[]){
#
#     ofstream updateReviewFile; // Create a output file stream object for review.txt
#     updateReviewFile.open("review.txt"); // Open file to clear the existing data and input data to review.txt
#
#     // Update latest review data into review.txt
#     for(int i=0; i<num_review; i++){
#
#         updateReviewFile << review_user_id[i] << "\t"
#         << review_rating[i] << "\t"
#         << review_statement[i] << "\t"
#         << review_hotel_name[i] << endl;
#     }
#
#     // Display appropriate message to tell user whether the data is saved into the file
#     if (updateReviewFile.is_open()){
#         cout << "\033[1;93m" << "\nLatest review data have been successfully updated to review.txt!" << "\033[0m"; // Display message in yellow and reset it at the end
#     }
#     else{
#         cout << "\033[1;91m" << "\nData fails to be updated to review.txt!" << "\033[0m"; // Display message in red and reset it at the end
#     }
#
#     // Close the output file stream object after update data into the file
#     updateReviewFile.close();
# }
#
# int main(){
#
#     // Create array for users.txt file
#     string user_id[MAX_USERS],
#     user_name[MAX_USERS],
#     country[MAX_USERS],
#     state[MAX_USERS],
#     email[MAX_USERS],
#     membership_category[MAX_USERS];
#
#     int current_points[MAX_USERS],
#     count_review[MAX_USERS];
#
#     // Create array for review.txt
#     string review_user_id[MAX_REVIEWS],
#     review_statement[MAX_REVIEWS],
#     review_hotel_name[MAX_REVIEWS],
#     hotel_name[MAX_REVIEWS];
#
#     int review_rating [MAX_REVIEWS],
#     number_word_review_statement[MAX_REVIEWS],
#     number_review_hotel[MAX_REVIEWS],
#     total_rating_hotel[MAX_REVIEWS];
#
#     // Call readUsers function to read data into array and find the number of users
#     int num_user = readUsers(user_id, user_name, country, state, email, membership_category, current_points);
#
#     // Call readReview function to read data into array and find the number of reviews
#     int num_review = readReview(review_user_id, review_rating, review_statement, review_hotel_name);
#
#     // Call function to find the number of word of each review
#     calculateNumWordReviewStatement(review_statement, number_word_review_statement,num_review);
#
#     // Call function to recalculate current points
#     int total_points_awarded = recalculatePoints(user_id, review_user_id, current_points, number_word_review_statement, num_user, num_review);
#
#     // Copy array for membership uprade notification purpose
#     string copy_membership_category[MAX_USERS];
#
#     // Loop to copy the membership category
#     for (int i=0; i<num_user; i++){
#         copy_membership_category[i] = membership_category[i];
#     }
#
#     // Call function to update membership category
#     updateMembershipCategory(user_id, membership_category, current_points, num_user, copy_membership_category, user_name);
#
#     // Call function to find the number of hotel & record the unique hotel name
#     int number_hotel = calculateNumHotel(review_hotel_name, num_review, hotel_name);
#
#     // Call function to calculate number of review and rating of a hotel
#     calculateNumReviewHotel(review_hotel_name, review_rating, num_review, number_hotel, hotel_name, number_review_hotel, total_rating_hotel);
#
#     // Copy array for sorting purpose
#     string copy_user_id[MAX_USERS],
#     copy_user_name[MAX_USERS],
#     sort_membership_category[MAX_USERS],
#     copy_hotel_name[MAX_REVIEWS];
#
#     int copy_current_points[MAX_USERS],
#     copy_number_review_hotel[MAX_REVIEWS],
#     copy_total_rating_hotel[MAX_REVIEWS];
#
#     // Create menu-driven interface
#     // Declare variables used for output features
#     double choice_double;
#     int choice = 0;
#     string input_user_id;
#
#     // Input Data Validation
#     while (choice != 12){
#
#         // Display Header
#         cout << "\033[1;95m\n====================== TRAVELGO MAIN MENU ======================\033[0m" << endl;
#         cout << "\033[1;94m[1]\033[0m  Display User Reviews" << endl;
#         cout << "\033[1;94m[2]\033[0m  Display Hotel Reviews" << endl;
#         cout << "\033[1;94m[3]\033[0m  User Information" << endl;
#         cout << "\033[1;94m[4]\033[0m  Positive Hotel Reviews" << endl;
#         cout << "\033[1;94m[5]\033[0m  Activity Summary" << endl;
#         cout << "\033[1;94m[6]\033[0m  Membership Categories" << endl;
#         cout << "\033[1;94m[7]\033[0m  Reviewer Leaderboard" << endl;
#         cout << "\033[1;94m[8]\033[0m  Top 3 Reviewers" << endl;
#         cout << "\033[1;94m[9]\033[0m  Hotel Rating Summary" << endl;
#         cout << "\033[1;94m[10]\033[0m Add Review" << endl;
#         cout << "\033[1;94m[11]\033[0m Serach Review by Word" << endl;
#         cout << "\033[1;94m[12]\033[0m Save & Exit" << endl;
#         cout << "\033[1;95m================================================================\033[0m" << endl;
#
#         cout << "\nEnter your choice: ";
#         cin >> choice_double; // Read the entered value as double to make the choice always an int
#         cin.ignore(); // Flush the buffer
#         choice = choice_double; // Convert the choice from double to int
#
#         // Input Data Validation
#         while (choice < 1 || choice > 12){
#             cout << "\033[1;91m\nInvalid Choice!\n\n\033[0m"; // Display message in red colour and reset it to default at the end
#             cout << "Enter your choice: ";
#             cin >> choice_double; // Read the entered value as double to make the choice always an int
#             cin.ignore(); // Flush the buffer
#             choice = choice_double; // Convert the choice from double to int
#         }
#
#         switch(choice){
#
#             // Display All Reviews Written by a Specific User
#             case 1:
#
#                 cout << "Enter User ID: "; // Prompt user to make input
#                 cin >> input_user_id;
#                 cin.ignore();
#
#                 // Call function
#                 displaySpecificUserReview(user_id, user_name, review_user_id, review_rating, review_statement, review_hotel_name, input_user_id, num_review, num_user, choice);
#                 break;
#
#             // Display All Reviews for a specific hotel
#             case 2:
#             {   // Put curly braces as there is variable declared inside the case
#                 int choice_hotel;
#                 double choice_hotel_double;
#
#                 // Display Available Hotel
#                 cout << endl << "\033[1;91m" <<  "Available Hotel List: \n" << "\033[0m" << endl;
#                 for (int i=0; i<number_hotel; i++){
#                     cout << "\033[1;93m" << "[" <<  i + 1 << "] "  << hotel_name[i] << "\033[0m" << endl;
#                 }
#
#                 cout << endl << "Enter your hotel choice: "; // Prompt user to make input
#                 cin >> choice_hotel_double; // Read the entered value as double to make the choice always an int
#                 cin.ignore();   // Flush the buffer
#                 choice_hotel = choice_hotel_double - 1; // Convert the choice from double to int
#
#                 // Call Function
#                 displaySpecificHotelReview(choice_hotel, review_hotel_name, review_user_id, review_rating, review_statement, user_name, user_id, num_review, num_user, number_hotel, hotel_name);
#                 break;
#             }
#
#             // Display updated user information
#             case 3:
#
#                 cout << endl;
#
#                 // Call function
#                 displayUserLatestInfo(user_id, user_name, country, state, email, membership_category, current_points, num_user);
#                 break;
#
#             // Display All reviews with rating 4 or 5 for a specific hotel
#             case 4:
#             {   // Put curly braces as there is variable declared inside the case
#
#                 int choice_hotel;
#                 double choice_hotel_double;
#
#                 // Display Available Hotel
#                 cout << endl << "\033[1;91m" <<  "Available Hotel List: \n" << "\033[0m" << endl;
#                 for (int i=0; i<number_hotel; i++){
#                     cout << "\033[1;93m" << "[" <<  i + 1 << "] "  << hotel_name[i] << "\033[0m" << endl;
#                 }
#
#                 cout << endl << "Enter your hotel choice: "; // Prompt user to make input
#                 cin >> choice_hotel_double; // Read the entered value as double to make the choice always an int
#                 cin.ignore();   // Flush the buffer
#                 choice_hotel = choice_hotel_double - 1; // Convert the choice from double to int
#
#                 // Call Function
#                 displayHighRatingReview(choice_hotel, review_hotel_name, review_user_id, review_rating, review_statement, user_id, user_name, num_user, num_review, number_hotel, hotel_name);
#                 break;
#             }
#
#             // Display Summary of Activities
#             case 5:
#
#                 cout << endl;
#
#                 // Call Function
#                 displaySummaryActivities(num_user, num_review, total_points_awarded);
#                 break;
#
#             // Display users grouped by membership category
#             case 6:
#
#                 // Loop to copy array
#                 for (int i=0; i<num_user; i++){
#                     copy_user_id[i] = user_id[i];
#                     copy_user_name[i] = user_name[i];
#                     copy_current_points[i] = current_points[i];
#                     sort_membership_category[i] = membership_category[i];
#                 }
#
#                 // Call Function
#                 displayUsersByMembership(copy_user_id, copy_user_name, sort_membership_category, copy_current_points, num_user);
#                 break;
#
#             // Display Top Reviewer Leaderboard
#             case 7:
#
#                 // Loop to copy array
#                 for (int i=0; i<num_user; i++){
#                     copy_user_id[i] = user_id[i];
#                     copy_user_name[i] = user_name[i];
#                     copy_current_points[i] = current_points[i];
#                 }
#
#                 cout << endl;
#
#                 // Call function
#                 displayTopReviewerLeaderboard(num_user, count_review, copy_user_id, copy_user_name, copy_current_points);
#                 break;
#
#             // Display Top 3 Users with most reviews
#             case 8:
#
#                 // Loop to copy array
#                 for (int i=0; i<num_user; i++){
#                     copy_user_id[i] = user_id[i];
#                     copy_user_name[i] = user_name[i];
#                     copy_current_points[i] = current_points[i];
#                 }
#
#                 cout << endl;
#
#                 // Call Function
#                 displayTop3Reviewer(num_user, count_review, copy_user_id, copy_user_name, copy_current_points);
#                 break;
#
#             // Display Hotel Rating Summary
#             case 9:
#
#                 // Copy array for sorting purpose
#                 for (int i=0; i<number_hotel; i++){
#                     copy_hotel_name[i] = hotel_name[i];
#                     copy_number_review_hotel[i] = number_review_hotel[i];
#                     copy_total_rating_hotel[i] = total_rating_hotel[i];
#                 }
#
#                 // Call Function
#                 displayHotelRatingSummary(number_hotel, copy_hotel_name, copy_number_review_hotel, copy_total_rating_hotel);
#                 break;
#
#             // Add new review
#             case 10:
#             {   // Put curly braces as there is variable declared inside the case
#                 cout << endl;
#
#                 // Call Function
#                 number_hotel = addNewReview(num_review, num_user, review_user_id, user_id, current_points, review_hotel_name, review_statement, review_rating, hotel_name, number_review_hotel, total_rating_hotel);
#
#                 // Update number of review
#                 num_review++;
#
#                 // Update the total points awarded
#                 int count = 1;
#                 // Count the number of character of the review statement made
#                 for (char temp: review_statement[num_review]){
#
#                         if(temp == ' '){
#                             count++;
#                         }
#
#                 }
#                 if (count >= 50){
#                     total_points_awarded += ( 100 + ((count / 50) * 10) );
#                 }
#                 else{
#                     total_points_awarded += 100;
#                 }
#
#                 // Loop to copy the membership category
#                 for (int i=0; i<num_user; i++){
#                     copy_membership_category[i] = membership_category[i];
#                 }
#
#                 // Call function to update the membership category based on the latest points
#                 updateMembershipCategory(user_id, membership_category, current_points, num_user, copy_membership_category, user_name);
#                 break;
#             }
#
#             // Serach review by word
#             case 11:
#             {   // Put curly braces as there is variable declared inside the case
#                 string keyword;
#                 cout << "Enter keyword to search: ";
#                 getline(cin, keyword);
#
#                 keyword = toLower(keyword); // Call function to lowercase the entered keyword
#
#                 // Call function to search review by word
#                 searchReviewByWord(num_review,num_user, keyword, review_statement, user_id, review_user_id, user_name, review_hotel_name, review_rating);
#                 break;
#             }
#         }
#     }
#
#     // Call function to update users.txt
#     updateUserFile(num_user, user_id, user_name, country, state, email, membership_category, current_points);
#
#     // Call function to update review.txt
#     updateReviewFile(num_review, review_user_id, review_rating, review_statement, review_hotel_name);
#
#     cout << "\033[1;93m" << "\n\nThank you for using TravelGo system! Goodbye.\n" << "\033[0m"; // Display message in yellow and reset it at the end
#     return 0;
# }
# Out:
# Overwriting travelgo.cpp

# %%
# %%shell
# g++ travelgo.cpp -o travelgo.elf
# ./travelgo.elf
# Out:
# ============================= Membership Upgrades ===============================
#
# |UserID    |Username            |Old Category   |New Category   |Current Points |
# +----------+--------------------+---------------+---------------+---------------+
# |U001      |Alice Morgan        |Gold           |Platinum       |10000          |
# +----------+--------------------+---------------+---------------+---------------+
#
# ====================== TRAVELGO MAIN MENU ======================
# [1]  Display User Reviews
# [2]  Display Hotel Reviews
# [3]  User Information
# [4]  Positive Hotel Reviews
# [5]  Activity Summary
# [6]  Membership Categories
# [7]  Reviewer Leaderboard
# [8]  Top 3 Reviewers
# [9]  Hotel Rating Summary
# [10] Add Review
# [11] Serach Review by Word
# [12] Save & Exit
# ...
#
# Enter your choice: 1
# Enter User ID: U001
#
# ...
#          User Review 1
# ...
# User ID        : U001
# Username       : Alice Morgan
# Rating         : 5/5
# Hotel Name     : Sunrise Hotel
# ...

# %%
import os
with open("users.txt","r") as file:
  print(file.read())
# Out:
# U001	Alice Morgan	Orange	California	alice.morgan@yahoo.com	Platinum	10000
# U002	Brian Chen	King	Washington	brian.chen@aol.com	Silver	3800
# U003	Sandra Lee	Clark	Nevada	sandra.lee@yahoo.com	Platinum	13250
# U004	Darren Low	Penang	Penang	darren.low@botmail.com	Silver	4400
# U005	Nur Aisha	Sepang	Selangor	aisha.nur@hotmail.com	Gold	8100
# U006	Hiro Tanaka	Osaka	Kansai	hiro.tanaka@mail.com	Silver	2700
# U007	Maria Gutierrez	Travis	Texas	m.gutierrez@example.com	Platinum	16000
# U008	John Peterson	Cook	Illinois	john.p@hotmail.com	Gold	6400
# U009	Lim Wei Jian	Johor Bahru	Johor	wj.lim@example.com	Silver	3200
# U010	Kavita Sharma	Mumbai	Maharashtra	kavita.sharma@yahoo.com	Gold	7700
# U011	Fiona Khalid	Gombak	Selangor	fiona.khalid@example.com	Silver	2500
# U012	Owen Riley	Maricopa	Arizona	owen.r@exhotmailample.com	Gold	6000
# U013	Chen Mei Lin	Tainan	Taiwan	meilin.chen@example.com	Silver	2800
# U014	James Walker	Miami-Dade	Florida	j.walker@aol.com	Platinum	11100
# ...

# %%
import os
with open("review.txt","r") as file:
  print(file.read())
# Out:
# U001	5	Great service and clean room	Sunrise Hotel
# U002	3	Average, nothing special	Maple Stay
# U002	4	Comfortable and quiet	Royal Palace
# U004	5	Staff very friendly	Ocean Dream Resort
# U005	2	Room too small	Sunrise Hotel
# U006	5	Excellent food	Hotel Sakura
# U007	4	Nice pool and gym	Grand Imperial
# U008	1	Bad experience with staff	CityView Hotel
# U009	3	Quite okay	Ocean Dream Resort
# U010	5	Loved the ambience	Lotus Bay Resort
# U011	4	Good for short stays	CityView Hotel
# U012	3	Fair price and fair quality	Maple Stay
# U013	2	Aircond noisy	Hotel Sakura
# U014	5	Perfect holiday	Royal Palace
# U015	4	Spacious lobby	Lotus Bay Resort
# U016	3	Breakfast average	Grand Imperial
# U017	5	Very satisfied	Sunrise Hotel
# U018	4	Clean and modern	CityView Hotel
# U019	3	Acceptable	Maple Stay
# U020	5	Top-notch luxury	Royal Palace
# U008	4	Nice Food	Sunrise Hotel

# %% [markdown]
# # Sample of program runs.
#
# This section demonstrates the execution of the program. It begins by loading the input files ('users.txt' and 'review.txt') and displaying the Main Menu, allowing the user to navigate through options 1 to 12:
#
# ```
# [1]  Display User Reviews
# [2]  Display Hotel Reviews
# [3]  User Information
# [4]  Positive Hotel Reviews
# [5]  Activity Summary
# [6]  Membership Categories
# [7]  Reviewer Leaderboard
# [8]  Top 3 Reviewers
# [9]  Hotel Rating Summary
# [10] Add Review
# [11] Serach Review by Word
# [12] Save & Exit
# ```
#
# ---

# %% [markdown]
# ## [1] Display User Reviews
#
# In this section, we demonstrate the process of retrieving and viewing reviews submitted by a specific user.
#
# When the user selects this option, the program requests a User ID as input. The system then performs a validation check against the current database to determine the appropriate outcome. Since the program processes data in real-time, any new reviews added during the current session (via the Add Review function) will be immediately accessible and visible in this list.
#
# **Logic & Outcomes:**
#
# - **Scenario 1: User Exists with Reviews**. If the User ID is valid and the user has submitted reviews, the program retrieves and displays a structured list of all their reviews, including the hotel name, rating, and statement.
#
# - **Scenario 2: User Exists but No Reviews**. If the User ID is found in the database but no matching records exist in the review file, the program displays the specific message: **"This user doesn't make any review"**.
#
# - **Scenario 3: User Does Not Exist**. If the entered User ID cannot be found in the system at all, the program immediately displays the error message: **"User not found"**.
#
# **Step-by-Step Execution:**
#
# 1. Program directs the user to the Main Menu.
#
# 2. User selects Menu choice [1] Display User Reviews by inputting 1.
#
# 3. Program prompts the user to enter a target User ID.
#
# 4. Program searches the global arrays to validate the input:
#
# - If the User ID is invalid: The system displays "User not found".
#
# - If the User ID is valid but has no reviews: The system displays "This user doesn't make any review".
#
# - If reviews are found: The system lists the user's name followed by their review details (Hotel, Rating, Statement), including any newly created reviews.
#
# 5. Program redirects to the menu for further actions.

# %%
# %%shell
# g++ travelgo.cpp -o travelgo.elf
# ./travelgo.elf
# Out:
# ====================== TRAVELGO MAIN MENU ======================
# [1]  Display User Reviews
# [2]  Display Hotel Reviews
# [3]  User Information
# [4]  Positive Hotel Reviews
# [5]  Activity Summary
# [6]  Membership Categories
# [7]  Reviewer Leaderboard
# [8]  Top 3 Reviewers
# [9]  Hotel Rating Summary
# [10] Add Review
# [11] Serach Review by Word
# [12] Save & Exit
# ...
#
# Enter your choice: 1
# Enter User ID: U001
#
# ...
#          User Review 1
# ...
# User ID        : U001
# Username       : Alice Morgan
# Rating         : 5/5
# Hotel Name     : Sunrise Hotel
# Statement      : Great service and clean room
#
# ====================== TRAVELGO MAIN MENU ======================
# [1]  Display User Reviews
# [2]  Display Hotel Reviews
# [3]  User Information
# [4]  Positive Hotel Reviews
# [5]  Activity Summary
# [6]  Membership Categories
# [7]  Reviewer Leaderboard
# [8]  Top 3 Reviewers
# [9]  Hotel Rating Summary
# [10] Add Review
# [11] Serach Review by Word
# [12] Save & Exit
# ...
#
# ...

# %% [markdown]
# ## [2] Display Hotel Reviews
#
# In this section, we demonstrate the functionality for retrieving and displaying all reviews associated with a specific hotel.
#
# When the user selects this option, the program first generates and displays a numbered list of all hotels currently recorded in the system. The user is then prompted to select a target hotel by its number. The system performs a cross-reference lookup to identify every review entry matching the selected hotel.
#
# **Logic & Outcomes:**
#
# - **Scenario 1: Successful Retrieval**. Upon selecting a valid hotel, the system iterates through the review database. For each match found, the program resolves the reviewer's User ID to their Username and displays the full review details, including the rating and the review statement. Since the hotel list is derived from existing reviews, every hotel listed is guaranteed to have at least one review record.
#
# - **Scenario 2: Real-Time Updates**. This function operates on the current data in memory. Therefore, if a new review was added via the Add Review function earlier in the session, it will be immediately included in this display.
#
# **Step-by-Step Execution:**
#
# 1. Program directs the user to the Main Menu.
#
# 2. User selects Menu choice [2] Display Hotel Reviews by inputting 2.
#
# 3. Program displays a numbered list of available hotels.
#
# 4. User inputs the index number corresponding to their desired hotel.
#
# 5. Program searches the global review arrays for matches.
#
# 6. The system displays the hotel name followed by the list of reviews (Username, Rating, Statement).
#
# 7. Program redirects to the menu for further actions.

# %%
# %%shell
# g++ travelgo.cpp -o travelgo.elf
# ./travelgo.elf
# Out:
# ====================== TRAVELGO MAIN MENU ======================
# [1]  Display User Reviews
# [2]  Display Hotel Reviews
# [3]  User Information
# [4]  Positive Hotel Reviews
# [5]  Activity Summary
# [6]  Membership Categories
# [7]  Reviewer Leaderboard
# [8]  Top 3 Reviewers
# [9]  Hotel Rating Summary
# [10] Add Review
# [11] Serach Review by Word
# [12] Save & Exit
# ...
#
# Enter your choice: 2
#
# Available Hotel List:
#
# [1] Sunrise Hotel
# [2] Maple Stay
# [3] Royal Palace
# [4] Ocean Dream Resort
# [5] Hotel Sakura
# [6] Grand Imperial
# [7] CityView Hotel
# [8] Lotus Bay Resort
#
# Enter your hotel choice: 1
#
# ...
#          Hotel Review 1
# ...
# User ID        : U001
# Username       : Alice Morgan
# Rating         : 5/5
# Statement      : Great service and clean room
#
# ...
#          Hotel Review 2
# ...
# User ID        : U005
# Username       : Nur Aisha
# Rating         : 2/5
# Statement      : Room too small
#
# ...
#          Hotel Review 3
# ...
# User ID        : U017
# ...

# %% [markdown]
# ## [3] User Information
#
# In this section, we demonstrate the system's ability to generate a comprehensive overview of all registered users.
#
# When this option is selected, the program retrieves the most current data from the memory arrays and displays it in a formatted table. This feature is particularly useful for verification purposes, as it reflects the latest status of every user. If points were added or membership categories were upgraded during the current session (e.g., via the Add Review or Membership Categories functions), those changes will be visible here immediately.
#
# **Logic & Outcomes:**
#
# - **Scenario: Full Profile Display**. The system iterates through the entire user database and outputs a structured table. For each user, the following details are displayed:
#
#   - **Personal Details:** User ID, Name, Email, Country, and State.
#
#   - **Gamification Status:** Current Points and Membership Category (e.g., Basic, Silver, Gold, Platinum).
#
# **Step-by-Step Execution:**
#
# 1. Program directs the user to the Main Menu.
#
# 2. User selects Menu choice [3] User Information by inputting 3.
#
# 3. Program generates a table header for readability.
#
# 4. Program iterates through the user arrays and prints every registered user's full profile to the console.
#
# 5. After the table is fully displayed, the program redirects to the menu for further actions.

# %%
# %%shell
# g++ travelgo.cpp -o travelgo.elf
# ./travelgo.elf
# Out:
# ====================== TRAVELGO MAIN MENU ======================
# [1]  Display User Reviews
# [2]  Display Hotel Reviews
# [3]  User Information
# [4]  Positive Hotel Reviews
# [5]  Activity Summary
# [6]  Membership Categories
# [7]  Reviewer Leaderboard
# [8]  Top 3 Reviewers
# [9]  Hotel Rating Summary
# [10] Add Review
# [11] Serach Review by Word
# [12] Save & Exit
# ...
#
# Enter your choice: 3
#
# |UserID    |Username            |Country        |State             |Email Address                 |Membership Category      |Current Points |
# +----------+--------------------+---------------+------------------+------------------------------+-------------------------+---------------+
# |U001      |Alice Morgan        |Orange         |California        |alice.morgan@yahoo.com        |Platinum                 |10300          |
# +----------+--------------------+---------------+------------------+------------------------------+-------------------------+---------------+
# ...

# %% [markdown]
# ## [4] Positive Hotel Reviews
#
# In this section, we demonstrate the system’s capability to filter and display high-quality feedback. This function allows users to view only the "Positive" reviews (defined as ratings of 4 or 5 stars) for a selected hotel.
#
# Similar to the standard hotel review display, the program first generates a numbered list of available hotels for selection. However, the retrieval process includes an additional conditional check to exclude any reviews with a rating below 4. This feature is useful for identifying the best-performing aspects of a specific hotel based on the latest real-time data.
#
# **Logic & Outcomes:**
#
# - **Scenario 1: Positive Reviews Exist**. If the selected hotel has reviews with a rating of 4 or 5, the system retrieves these specific entries. It resolves the reviewer's User ID to a Username and displays the review details.
#
# - **Scenario 2: No Positive Reviews Found**. It is possible for a hotel to exist in the system (having only low ratings, e.g., 1-3 stars). In this case, if the filter finds no matches meeting the "Positive" criteria, the program displays the specific notification: "No positive reviews found for this hotel."
#
# - **Scenario 3: Invalid Hotel Selection**. If the user enters an index number that is not currently in the generated list (e.g., entering "5" when only 3 hotels are listed), the program detects the invalid input and displays the error message: "Hotel not found! Please use the hotel listed above!".
#
# **Step-by-Step Execution:**
#
# 1. Program directs the user to the Main Menu.
#
# 2. User selects Menu choice [4] Positive Hotel Reviews by inputting 4.
#
# 3. Program displays a numbered list of available hotels.
#
# 4. User inputs the index number corresponding to their desired hotel.
#
# 5. Program validates the input index:
#
# - If the index is out of range: The system displays "Hotel not found! Please use the hotel listed above!".
#
# - If the index is valid: The program proceeds to filter the reviews.
#
# 6. For a valid hotel, the program searches for reviews with Rating $\ge$ 4.
#
# - If found, positive reviews are listed.
#
# - If not found, the "No positive reviews" message is shown.
#
# 7. Program redirects to the menu for further actions.

# %%
# %%shell
# g++ travelgo.cpp -o travelgo.elf
# ./travelgo.elf
# Out:
# ====================== TRAVELGO MAIN MENU ======================
# [1]  Display User Reviews
# [2]  Display Hotel Reviews
# [3]  User Information
# [4]  Positive Hotel Reviews
# [5]  Activity Summary
# [6]  Membership Categories
# [7]  Reviewer Leaderboard
# [8]  Top 3 Reviewers
# [9]  Hotel Rating Summary
# [10] Add Review
# [11] Serach Review by Word
# [12] Save & Exit
# ...
#
# Enter your choice: 4
#
# Available Hotel List:
#
# [1] Sunrise Hotel
# [2] Maple Stay
# [3] Royal Palace
# [4] Ocean Dream Resort
# [5] Hotel Sakura
# [6] Grand Imperial
# [7] CityView Hotel
# [8] Lotus Bay Resort
#
# Enter your hotel choice: 1
#
# ...
#          Hotel Review 1
# ...
# User ID        : U001
# Username       : Alice Morgan
# Rating         : 5/5
# Statement      : Great service and clean room
#
# ...
#          Hotel Review 2
# ...
# User ID        : U017
# Username       : Emily Johnson
# Rating         : 5/5
# Statement      : Very satisfied
#
# ...
#          Hotel Review 3
# ...
# User ID        : U008
# ...

# %% [markdown]
# ## [5] Activity Summary
#
# In this section, we demonstrate the system’s ability to generate a high-level statistical overview of the current database.
#
# When this option is selected, the program aggregates and displays key metrics regarding the system's usage. This function acts as a real-time dashboard, providing an immediate snapshot of the total volume of data (users and reviews) and the total value of gamification rewards (points) currently distributed in the system. As users register or new reviews are added, these counters are automatically updated and reflected here.
#
# **Logic & Outcomes:**
#
# - **Scenario: Statistical Overview**. The system retrieves the current values of the global counters and accumulators. It then formats and displays three critical metrics:
#
# 1. **Total Number of Users:** The count of currently registered users.
#
# 2. **Total Number of Reviews:** The count of all valid reviews stored in the system.
#
# 3. **Total Points Awarded:** The sum of all gamification points currently held by all users.
#
# **Step-by-Step Execution:**
#
# 1. Program directs the user to the Main Menu.
#
# 2. User selects Menu choice [5] Activity Summary by inputting 5.
#
# 3. Program retrieves the latest values for user counts, review counts, and total system points.
#
# 4. Program displays the summary report to the console:
#
# - "Total Number of Users: [Count]"
#
# - "Total Number of Reviews: [Count]"
#
# - "Total Points Awarded: [Value]"
#
# 5. Program redirects to the menu for further actions.

# %%
# %%shell
# g++ travelgo.cpp -o travelgo.elf
# ./travelgo.elf
# Out:
# ====================== TRAVELGO MAIN MENU ======================
# [1]  Display User Reviews
# [2]  Display Hotel Reviews
# [3]  User Information
# [4]  Positive Hotel Reviews
# [5]  Activity Summary
# [6]  Membership Categories
# [7]  Reviewer Leaderboard
# [8]  Top 3 Reviewers
# [9]  Hotel Rating Summary
# [10] Add Review
# [11] Serach Review by Word
# [12] Save & Exit
# ...
#
# Enter your choice: 5
#
# Total number of users              : 20
# Total number of reviews            : 21
# Total points awarded system-wide   : 2100
#
# ====================== TRAVELGO MAIN MENU ======================
# [1]  Display User Reviews
# [2]  Display Hotel Reviews
# [3]  User Information
# [4]  Positive Hotel Reviews
# [5]  Activity Summary
# [6]  Membership Categories
# [7]  Reviewer Leaderboard
# [8]  Top 3 Reviewers
# [9]  Hotel Rating Summary
# [10] Add Review
# [11] Serach Review by Word
# [12] Save & Exit
# ...
#
# Enter your choice: 12
#
# ...

# %% [markdown]
# ## [6] Membership Categories
#
# In this section, we demonstrate how the system organizes users into distinct loyalty tiers based on their accumulated points.
#
# When selected, this function provides a structured, hierarchical view of the user base. Unlike the standard user list, this display separates users into four specific categories: Platinum, Gold, Silver, and Basic. To enhance readability and analysis, the program allows the administrator to sort the users within these categories based on their current_points, either in Ascending (lowest to highest) or Descending (highest to lowest) order.
#
# **Logic & Outcomes:**
#
# - **Scenario 1: Sorting Preference**. The user is prompted to choose a sorting order:
#
#   - **Ascending (1):** Users with fewer points appear first within their category.
#
#   - **Descending (2):** Users with the highest points appear at the top.The system uses a sorting algorithm (Bubble Sort) to reorder the user data in memory before display.
#
# - **Scenario 2: Tiered Display**. The program sequentially processes and displays users group by group in the following order: **Platinum $\to$ Gold $\to$ Silver $\to$ Basic.** This ensures high-value users are distinguished from new members.
#
# - **Scenario 3: Empty Categories**. If a specific membership tier (e.g., Platinum) currently has no qualified users, the system explicitly displays the message **"No users in this category"** under that section header, ensuring the report is complete and clear.
#
# **Step-by-Step Execution:**
#
# 1. Program directs the user to the Main Menu.
#
# 2. User selects Menu choice [6] Membership Categories by inputting 6.
#
# 3. Program prompts the user to select the Sort Order:
#
# - Input 1 for Ascending.
#
# - Input 2 for Descending.
#
# 4. Program sorts the global user arrays based on current_points according to the selected order.
#
# 5. Program iterates through the sorted data four times to display each category block:
#
# - Platinum: Displays users with $\ge$ 10,000 points.
#
# - Gold: Displays users with 5,000 - 9,999 points.
#
# - Silver: Displays users with 1,000 - 4,999 points.
#
# - Basic: Displays users with < 1,000 points.
#
# 6. Program redirects to the menu for further actions.

# %%
# %%shell
# g++ travelgo.cpp -o travelgo.elf
# ./travelgo.elf
# Out:
# ============================= Membership Upgrades ===============================
#
# |UserID    |Username            |Old Category   |New Category   |Current Points |
# +----------+--------------------+---------------+---------------+---------------+
# |U002      |Brian Chen          |Silver         |Gold           |5000           |
# +----------+--------------------+---------------+---------------+---------------+
# |U004      |Darren Low          |Silver         |Gold           |5000           |
# +----------+--------------------+---------------+---------------+---------------+
#
# ====================== TRAVELGO MAIN MENU ======================
# [1]  Display User Reviews
# [2]  Display Hotel Reviews
# [3]  User Information
# [4]  Positive Hotel Reviews
# [5]  Activity Summary
# [6]  Membership Categories
# [7]  Reviewer Leaderboard
# [8]  Top 3 Reviewers
# [9]  Hotel Rating Summary
# [10] Add Review
# [11] Serach Review by Word
# [12] Save & Exit
# ...
#
# Enter your choice: 6
#
# ...

# %% [markdown]
# ##[7] Reviewer Leaderboard
#
# In this section, we demonstrate the system’s ability to rank users based on their contribution levels.
#
# When selected, this function generates a "Hall of Fame" style leaderboard that ranks all users in descending order based on the number of reviews they have submitted. This feature serves to recognize top contributors and encourages user engagement through gamification. Since the system updates in real-time, any user who submits a new review will immediately see their position rise on this leaderboard if their new count surpasses others.
#
# **Logic & Outcomes:**
#
# - **Scenario 1: Sorting by Contribution**. The program calculates the review count for every user and executes a sorting algorithm (Bubble Sort) to arrange the users from highest contributor to lowest.
#
# - **Scenario 2: Handling Ties (Shared Ranks)**. The system includes intelligent ranking logic to handle cases where multiple users have the exact same number of reviews.
#
#   - If User A and User B both have 10 reviews, they will share the same rank (e.g., both are Rank 1).
#
#   - The next user (User C with 9 reviews) will be assigned the actual position in the list (e.g., Rank 3), skipping the intermediate number. This ensures the ranking accurately reflects the statistical distribution.
#
# **Step-by-Step Execution:**
#
# 1. Program directs the user to the Main Menu.
#
# 2. User selects Menu choice [7] Reviewer Leaderboard by inputting 7.
#
# 3. Program calculates the current review statistics for all users.
#
# 4. Program sorts the user list in Descending Order (Highest to Lowest).
#
# 5. Program iterates through the sorted list, calculates the specific Rank (handling any ties), and displays the leaderboard:
#
# - Format: [Rank] | [User ID] | [Name] | [Review Count]
#
# 6. Program redirects to the menu for further actions.

# %%
# %%shell
# g++ travelgo.cpp -o travelgo.elf
# ./travelgo.elf
# Out:
# ====================== TRAVELGO MAIN MENU ======================
# [1]  Display User Reviews
# [2]  Display Hotel Reviews
# [3]  User Information
# [4]  Positive Hotel Reviews
# [5]  Activity Summary
# [6]  Membership Categories
# [7]  Reviewer Leaderboard
# [8]  Top 3 Reviewers
# [9]  Hotel Rating Summary
# [10] Add Review
# [11] Serach Review by Word
# [12] Save & Exit
# ...
#
# Enter your choice: 7
#
# |Rankings  |UserID    |Username            |Number of Review Made |
# +----------+----------+--------------------+----------------------+
# |1         |U007      |Maria Gutierrez     |167                   |
# +----------+----------+--------------------+----------------------+
# |2         |U020      |Adrian Yong         |148                   |
# +----------+----------+--------------------+----------------------+
# |3         |U003      |Sandra Lee          |132                   |
# +----------+----------+--------------------+----------------------+
# ...

# %% [markdown]
# ##[8] Top 3 Reviewers
#
# In this section, we demonstrate the system’s ability to highlight the elite contributors within the user base.
#
# While the Leaderboard (Function 7) shows the complete standings, this function filters the data to display only the **top three ranking positions**. This provides a quick, focused view of the most active users ("The Winners"). This feature is particularly useful for identifying candidates for special rewards or recognition.
#
# **Logic & Outcomes:**
#
# - **Scenario 1: Standard Ranking**. The system calculates review counts and sorts all users in descending order. It then iterates through the list and displays users who hold Rank 1, Rank 2, or Rank 3. Once the ranking position exceeds 3, the display loop terminates.
#
# - **Scenario 2: Handling Ties**. in the Top 3 The system respects shared ranks during this filtering process.
#
#   - Example: If three users are tied for Rank 1, the system will display all three of them.
#
#   - Since they are all technically within the "Top 3" criteria (Rank 1 <= 3), the output may show more than three individual names if a tie occurs at the top.
#
# **Step-by-Step Execution:**
#
# 1. Program directs the user to the Main Menu.
#
# 2. User selects Menu choice [8] Top 3 Reviewers by inputting 8.
#
# 3. Program calculates statistics and performs a sort (Highest to Lowest).
#
# 4. Program initializes a ranking counter.
#
# 5. Program iterates through the sorted list:
#
# - It checks if the current user's rank is less than or equal to 3.
#
# - If yes, the user is displayed.
#
# - If the rank exceeds 3, the display process stops.
#
# 6. Program redirects to the menu for further actions.

# %%
# %%shell
# g++ travelgo.cpp -o travelgo.elf
# ./travelgo.elf
# Out:
# ====================== TRAVELGO MAIN MENU ======================
# [1]  Display User Reviews
# [2]  Display Hotel Reviews
# [3]  User Information
# [4]  Positive Hotel Reviews
# [5]  Activity Summary
# [6]  Membership Categories
# [7]  Reviewer Leaderboard
# [8]  Top 3 Reviewers
# [9]  Hotel Rating Summary
# [10] Add Review
# [11] Serach Review by Word
# [12] Save & Exit
# ...
#
# Enter your choice: 8
#
# |Rankings  |UserID    |Username            |Number of Review Made |
# +----------+----------+--------------------+----------------------+
# |1         |U007      |Maria Gutierrez     |168                   |
# +----------+----------+--------------------+----------------------+
# |2         |U020      |Adrian Yong         |149                   |
# +----------+----------+--------------------+----------------------+
# |3         |U003      |Sandra Lee          |132                   |
# +----------+----------+--------------------+----------------------+
#
# ...

# %% [markdown]
# ##[9] Hotel Rating Summary
#
# In this section, we demonstrate the system’s ability to generate a comparative analysis of all hotels.
#
# When selected, this function calculates the average performance metrics for every hotel and presents a summary table. Unlike the basic hotel list, this feature allows the user to sort the data based on specific criteria, making it easier to identify the most popular hotels (highest review count) or the highest-quality hotels (best average rating).
#
# **Logic & Outcomes:**
#
# - **Criteria 1: Sort by Popularity (Review Count)**. The user can choose to rank hotels based on the volume of reviews.
#
#   - **Descending:** Shows the "busiest" or most frequently reviewed hotels at the top.
#
#   - **Ascending:** Shows the least reviewed hotels at the top.
#
# - **Criteria 2: Sort by Quality (Average Rating)**. The user can choose to rank hotels based on their calculated average rating (Total Rating / Number of Reviews).
#
#   - **Descending:** Shows the "Best Rated" hotels (e.g., 5.0 stars) at the top.
#
#   - **Ascending:** Shows the lowest-rated hotels at the top.
#
# - **Data integrity:** The system automatically filters the list to ensure only hotels with at least one active review are displayed, preventing "divide by zero" errors and ensuring the table remains relevant.
#
# **Step-by-Step Execution:**
#
# 1. Program directs the user to the Main Menu.
#
# 2. User selects Menu choice [9] Hotel Rating Summary by inputting 9.
#
# 3. Program prompts for the Sorting Criteria:
#
# - Input 1 for Review Count.
#
# - Input 2 for Average Rating.
#
# 4. Program prompts for the Sort Order:
#
# - Input 1 for Ascending.
#
# - Input 2 for Descending.
#
# 5. Program performs the calculations and sorts the data arrays accordingly.
#
# 6. Program displays the Hotel Rating Summary Table with columns for Hotel Name, Average Rating, and Number of Reviews.
#
# 7. Program redirects to the menu for further actions.

# %%
# %%shell
# g++ travelgo.cpp -o travelgo.elf
# ./travelgo.elf
# Out:
# ====================== TRAVELGO MAIN MENU ======================
# [1]  Display User Reviews
# [2]  Display Hotel Reviews
# [3]  User Information
# [4]  Positive Hotel Reviews
# [5]  Activity Summary
# [6]  Membership Categories
# [7]  Reviewer Leaderboard
# [8]  Top 3 Reviewers
# [9]  Hotel Rating Summary
# [10] Add Review
# [11] Serach Review by Word
# [12] Save & Exit
# ...
#
# Enter your choice: 9
#
# ...
#    Sorting Features Menu
# ...
# 1. Sort by Number of Review
# 2. Sort by Rating
#
# Enter your choice: 3
#
# Invalid Choice! Please make input again!
#
# ...
#    Sorting Features Menu
# ...
# 1. Sort by Number of Review
# 2. Sort by Rating
#
# Enter your choice: 1
#
# ...
#    Sorting Features Menu
# ...
# 1. Ascending Order
# 2. Descending Order
#
# Enter your choice: 3
#
# Invalid Choice! Please make input again!
#
# ...
#    Sorting Features Menu
# ...
# 1. Ascending Order
# 2. Descending Order
#
# Enter your choice: 1
#
# |Hotel Name                    |Average Rating      |Number of Review    |
# ...

# %% [markdown]
# ##[10] Add Review
#
# In this section, we demonstrate the core functionality that allows users to contribute data to the system.
#
# When selected, this function initiates a guided data entry process. Unlike a simple text input, this feature includes strict Validation Loops to ensure data integrity (e.g., preventing the use of invalid User IDs or impossible ratings). Furthermore, this function triggers the Gamification Engine, automatically calculating and awarding reward points to the user based on the quality (length) of their review immediately after submission.
#
# **Logic & Outcomes:**
#
# - **Validation Loops (Error Prevention)**
#
#   - **User Verification:** The system prompts for a User ID. If the ID does not exist in the database, the system rejects it, displays an error, and loops back to ask again. This ensures every review is linked to a valid user.
#
#   - **Rating Verification:** The system enforces a standard 1-5 star scale. If the user enters a number outside this range (e.g., 0 or 6), the input is rejected until a valid rating is provided.
#
# - **Gamification (Points Calculation)** Once the review is accepted, the system calculates the user's reward in real-time:
#
#   - **Base Reward:** Every review earns a standard 100 points.
#
#   - **Quality Bonus:** The system analyzes the word count of the review statement. If the review contains 50 words or more, the user earns additional bonus points (calculated as Words / 50 * 10). These points are immediately added to the user's current_points profile.
#
# **Step-by-Step Execution:**
#
# 1. Program directs the user to the Main Menu.
#
# 2. User selects Menu choice [10] Add Review by inputting 10.
#
# 3. User ID Loop: Program prompts for User ID. The user cannot proceed until a valid ID is entered.
#
# 4. Program prompts for the Hotel Name and Review Statement.
#
# 5. Rating Loop: Program prompts for a Rating. The system forces the user to enter a value between 1 and 5.
#
# 6. Processing:
#
# - The new review is appended to the global arrays.
#
# - The user's points are recalculated and updated.
#
# - The hotel statistics (total reviews/ratings) are refreshed.
#
# 7. Program redirects to the Main Menu.

# %%
# %%shell
# g++ travelgo.cpp -o travelgo.elf
# ./travelgo.elf
# Out:
# ====================== TRAVELGO MAIN MENU ======================
# [1]  Display User Reviews
# [2]  Display Hotel Reviews
# [3]  User Information
# [4]  Positive Hotel Reviews
# [5]  Activity Summary
# [6]  Membership Categories
# [7]  Reviewer Leaderboard
# [8]  Top 3 Reviewers
# [9]  Hotel Rating Summary
# [10] Add Review
# [11] Serach Review by Word
# [12] Save & Exit
# ...
#
# Enter your choice: 10
#
# Enter UserID: U002
# Enter Hotel Name: Sunrise Hotel
# Enter Review Statement: Bad Sercice
# Enter Rating (1-5): 3
#
# ====================== TRAVELGO MAIN MENU ======================
# [1]  Display User Reviews
# [2]  Display Hotel Reviews
# [3]  User Information
# [4]  Positive Hotel Reviews
# [5]  Activity Summary
# [6]  Membership Categories
# [7]  Reviewer Leaderboard
# [8]  Top 3 Reviewers
# [9]  Hotel Rating Summary
# [10] Add Review
# [11] Serach Review by Word
# [12] Save & Exit
# ...
#
# Enter your choice: 10
#
# Enter UserID: U021
#
# ...

# %% [markdown]
# ##[11] Search Review by Word
#
# In this section, we demonstrate the system’s text-searching capabilities.
#
# While other functions filter by Hotel or User, this function allows the user to perform a keyword-based search across the actual content of the review statements. This is particularly useful for analyzing specific themes or feedback trends (e.g., searching for the word "breakfast", "dirty", or "friendly") across the entire database.
#
# **Logic & Outcomes:**
#
# - **Mechanism: Substring Matching**. The system iterates through every review statement in the database. It checks if the user's input keyword exists anywhere within the review text (not just an exact match). This allows the system to find relevant sentences even if the keyword is in the middle of a paragraph.
#
# - **Feature: Case-Insensitivity**. To ensure comprehensive results, the search logic is case-insensitive. The program internally converts both the stored review statements and the user's search query to a uniform format (lowercase) before comparing.
#
#   - Example: A search for "CLEAN" will successfully find reviews containing "clean", "Clean", or "cLeAn".
#
# **Step-by-Step Execution:**
#
# 1. Program directs the user to the Main Menu.
#
# 2. User selects Menu choice [11] Search Review by Word by inputting 11.
#
# 3. Program prompts the user to enter a Search Keyword.
#
# 4. Program starts a traversal of the review array:
#
# - It converts the current review statement to lowercase.
#
# - It converts the search keyword to lowercase.
#
# - It checks if the keyword is present in the statement.
#
# 5. Outcome:
#
# - For every match found, the system resolves the User ID to a Name and displays the full review details (User ID, Name, Rating, Statement).
#
# 6. Program redirects to the menu for further actions.

# %%
# %%shell
# g++ travelgo.cpp -o travelgo.elf
# ./travelgo.elf
# Out:
# ====================== TRAVELGO MAIN MENU ======================
# [1]  Display User Reviews
# [2]  Display Hotel Reviews
# [3]  User Information
# [4]  Positive Hotel Reviews
# [5]  Activity Summary
# [6]  Membership Categories
# [7]  Reviewer Leaderboard
# [8]  Top 3 Reviewers
# [9]  Hotel Rating Summary
# [10] Add Review
# [11] Serach Review by Word
# [12] Save & Exit
# ...
#
# Enter your choice: 11
# Enter keyword to search: CLean
#
# ...
#          User Review 1
# ...
# User ID        : U001
# Username       : Alice Morgan
# Rating         : 5/5
# Hotel Name     : Sunrise Hotel
# Statement      : Great service and clean room
#
# ...
#          User Review 2
# ...
# User ID        : U018
# Username       : Rahul Nair
# Rating         : 4/5
# Hotel Name     : CityView Hotel
# Statement      : Clean and modern
#
# ====================== TRAVELGO MAIN MENU ======================
# [1]  Display User Reviews
# [2]  Display Hotel Reviews
# [3]  User Information
# [4]  Positive Hotel Reviews
# [5]  Activity Summary
# ...

# %% [markdown]
# ##[12] Save & Exit
#
# In this final section, we demonstrate the system’s data persistence capability and safe termination process.
#
# Since the program performs all operations (like adding reviews or updating points) in the computer's temporary memory (RAM), this function is crucial for saving that progress. It writes the current state of the arrays back into the physical text files (users.txt and review.txt), effectively updating the database for the next time the program is run.
#
# **Logic & Outcomes:**
#
# - **Data Serialization (Saving)** The program opens the source text files in Write Mode. It then iterates through the current arrays and overwrites the old file contents with the updated data. This ensures that:
#
#   - New reviews added during the session are stored.
#
#   - Updated point balances and membership changes are preserved.
#
# **Step-by-Step Execution:**
#
# 1. Program directs the user to the Main Menu.
#
# 2. User selects Menu choice [12] Save & Exit by inputting 12.
#
# 3. Saving Process:
#
# - The system writes all User Data from memory to users.txt.
#
# - The system writes all Review Data from memory to review.txt.
#
# 4. A success message "Data saved successfully" is displayed.
#
# 5. The program displays a farewell message: "Thank you for using TravelGo system! Goodbye."
#
# 6. The program terminates execution.

# %%
# %%shell
# g++ travelgo.cpp -o travelgo.elf
# ./travelgo.elf
# Out:
# ====================== TRAVELGO MAIN MENU ======================
# [1]  Display User Reviews
# [2]  Display Hotel Reviews
# [3]  User Information
# [4]  Positive Hotel Reviews
# [5]  Activity Summary
# [6]  Membership Categories
# [7]  Reviewer Leaderboard
# [8]  Top 3 Reviewers
# [9]  Hotel Rating Summary
# [10] Add Review
# [11] Serach Review by Word
# [12] Save & Exit
# ...
#
# Enter your choice: 3
#
# |UserID    |Username            |Country        |State             |Email Address                 |Membership Category      |Current Points |
# +----------+--------------------+---------------+------------------+------------------------------+-------------------------+---------------+
# |U001      |Alice Morgan        |Orange         |California        |alice.morgan@yahoo.com        |Platinum                 |11200          |
# +----------+--------------------+---------------+------------------+------------------------------+-------------------------+---------------+
# ...

# %%
import os
with open("users.txt","r") as file:
  print(file.read())
# Out:
# U001	Alice Morgan	Orange	California	alice.morgan@yahoo.com	Platinum	11200
# U002	Brian Chen	King	Washington	brian.chen@aol.com	Gold	6500
# U003	Sandra Lee	Clark	Nevada	sandra.lee@yahoo.com	Platinum	13250
# U004	Darren Low	Penang	Penang	darren.low@botmail.com	Gold	5600
# U005	Nur Aisha	Sepang	Selangor	aisha.nur@hotmail.com	Gold	9600
# U006	Hiro Tanaka	Osaka	Kansai	hiro.tanaka@mail.com	Silver	3900
# U007	Maria Gutierrez	Travis	Texas	m.gutierrez@example.com	Platinum	17200
# U008	John Peterson	Cook	Illinois	john.p@hotmail.com	Gold	8800
# U009	Lim Wei Jian	Johor Bahru	Johor	wj.lim@example.com	Silver	4400
# U010	Kavita Sharma	Mumbai	Maharashtra	kavita.sharma@yahoo.com	Gold	8900
# U011	Fiona Khalid	Gombak	Selangor	fiona.khalid@example.com	Silver	3700
# U012	Owen Riley	Maricopa	Arizona	owen.r@exhotmailample.com	Gold	7200
# U013	Chen Mei Lin	Tainan	Taiwan	meilin.chen@example.com	Silver	4000
# U014	James Walker	Miami-Dade	Florida	j.walker@aol.com	Platinum	12300
# ...

# %%
import os
with open("review.txt","r") as file:
  print(file.read())
# Out:
# U001	5	Great service and clean room	Sunrise Hotel
# U002	3	Average, nothing special	Maple Stay
# U002	4	Comfortable and quiet	Royal Palace
# U004	5	Staff very friendly	Ocean Dream Resort
# U005	2	Room too small	Sunrise Hotel
# U006	5	Excellent food	Hotel Sakura
# U007	4	Nice pool and gym	Grand Imperial
# U008	1	Bad experience with staff	CityView Hotel
# U009	3	Quite okay	Ocean Dream Resort
# U010	5	Loved the ambience	Lotus Bay Resort
# U011	4	Good for short stays	CityView Hotel
# U012	3	Fair price and fair quality	Maple Stay
# U013	2	Aircond noisy	Hotel Sakura
# U014	5	Perfect holiday	Royal Palace
# U015	4	Spacious lobby	Lotus Bay Resort
# U016	3	Breakfast average	Grand Imperial
# U017	5	Very satisfied	Sunrise Hotel
# U018	4	Clean and modern	CityView Hotel
# U019	3	Acceptable	Maple Stay
# U020	5	Top-notch luxury	Royal Palace
# U008	4	Nice Food	Sunrise Hotel
# U002	3	Bad Sercice	Sunrise Hotel
# U005	4	Good Service	New Hotel
